# %%
import sys
#sys.path.append('jars/mleap/python')
import mleap.pyspark
from pyspark.ml.linalg import Vectors
from mleap.pyspark.spark_support import SimpleSparkSerializer
from pyspark import SparkContext
from pyspark.sql import SparkSession,SQLContext
from pyspark.sql.functions import *
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, OneHotEncoder, StandardScaler, RFormula, VectorIndexer
from pyspark.ml.regression import GBTRegressor, GBTRegressionModel
from pyspark.ml.regression import RandomForestRegressor, DecisionTreeRegressor
from pyspark.ml import Pipeline, PipelineModel
from pyspark.sql.types import *

# %%
SparkContext.setSystemProperty('spark.driver.memory', '2g')
SparkContext.setSystemProperty('spark.driver.cores', '3')
SparkContext.setSystemProperty('spark.executor.memory', '2g')
SparkContext.setSystemProperty('spark.executor.cores', '3')
SparkContext.setSystemProperty('spark.driver.memoryOverhead', '1g')
SparkContext.setSystemProperty('spark.storage.memoryFraction', '0.9')

# %%
data_df = spark.read.csv('abt/data/*',header=True, inferSchema=True)
data_df.printSchema()
# Out:
# root
#  |-- idmovie: integer (nullable = true)
#  |-- runtime: integer (nullable = true)
#  |-- director: string (nullable = true)
#  |-- genres: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- budgetvalue: long (nullable = true)

# %% [markdown]
# ## Summary Statistics

# %% [markdown]
# #### Evaluating continuous features

# %%
data_df.summary().select('summary','budgetvalue', 'runtime','rating').show()
# Out:
# +-------+--------------------+------------------+------------------+
# |summary|         budgetvalue|           runtime|            rating|
# +-------+--------------------+------------------+------------------+
# |  count|               18495|             18495|             18495|
# |   mean|6.0121800647904836E7|100.06520681265206|3.1008229251148713|
# | stddev| 7.384994399567893E8|34.253022733437874|0.6089458576840447|
# |    min|                   1|                 0|               0.5|
# |    25%|             3000000|                91|              2.77|
# |    50%|            11500000|               101|              3.17|
# |    75%|            34000000|               116|              3.52|
# |    max|         35000000000|               359|               5.0|
# +-------+--------------------+------------------+------------------+

# %% [markdown]
# #### Defining Features

# %%
#'runtime', 'rating','budgetvalue'
continuous_cols  = ['rating']
categorical_cols = ['director','genres']

# %%
#def featuresCreation(df):

categorical_indexers = [
    StringIndexer(inputCol=column, outputCol="{0}_indexed".format(column), handleInvalid='keep')
    for column in categorical_cols
]

categorical_features = [
    OneHotEncoder(
        inputCol=indexer.getOutputCol(),
        outputCol="{0}_encoded".format(indexer.getOutputCol()))
    for indexer in categorical_indexers
]

continuous_feature = [VectorAssembler(
    inputCols=[column for column in continuous_cols],
    outputCol="continuous_features"
)]


all_features = continuous_feature + categorical_features

universal_assembler = VectorAssembler(
    inputCols=[feature.getOutputCol() for feature in all_features],
    outputCol="features"
)

gbt = GBTRegressor(featuresCol='features',labelCol='budgetvalue', maxDepth=6, maxIter=45)

stages = categorical_indexers + \
         categorical_features + \
         continuous_feature + \
         [universal_assembler] + \
         [gbt]

universal_pipeline = Pipeline(stages=stages)

# %%
(train_df, test_df) = data_df.randomSplit([0.80,0.20], 40)

# %%
### GRADIENT BOOSTING ##############################################################################################
#gbt                = GBTRegressor(featuresCol='features',labelCol='budgetvalue', maxDepth=6, maxIter=45)
gbt_model          = universal_pipeline.fit(train_df)#gbt.fit(train_df)
print("### MODEL TRAINED")
gbt_pred           = gbt_model.transform(test_df)
print("### MODEL PREDICTED")
gbt_evaluator_rmse = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='rmse')
gbt_rmse           = gbt_evaluator_rmse.evaluate(gbt_pred)
gbt_evaluator_r2   = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='r2')
gbt_r2             = gbt_evaluator_r2.evaluate(gbt_pred)

print('### GRADIENT BOOSTED RMSE:')
print(gbt_rmse)
print('### GRADIENT BOOSTED r2:')
print(gbt_r2)
# Out:
# ### MODEL TRAINED
# ### MODEL PREDICTED
# ### GRADIENT BOOSTED RMSE:
# 291029802.54118365
# ### GRADIENT BOOSTED r2:
# 0.6847638541277404

# %%
print('GRADIENT BOOSTED #########################')
gbt_pred.select('idmovie','director','genres','budgetvalue', 'prediction')\
        .withColumn('pred', gbt_pred['prediction'].cast(DecimalType(38,2)))\
        .drop('prediction')\
        .withColumnRenamed('pred', 'prediction').show(10)
# Out:
# GRADIENT BOOSTED #########################
# +-------+--------------+---------+-----------+-----------+
# |idmovie|      director|   genres|budgetvalue| prediction|
# +-------+--------------+---------+-----------+-----------+
# |      1| John Lasseter|Adventure|   30000000|40994034.42|
# |      1| John Lasseter|Animation|   30000000|30384369.20|
# |      1| John Lasseter|   Comedy|   30000000|30384369.20|
# |      2|  Joe Johnston|Adventure|   65000000|40994034.42|
# |      2|  Joe Johnston|  Fantasy|   65000000|30384369.20|
# |     15|  Renny Harlin|   Action|   98000000|38618105.45|
# |     20|  Joseph Ruben| Thriller|   68000000|30384369.20|
# |     23|Richard Donner|   Action|   50000000|38618105.45|
# |     23|Richard Donner|    Crime|   50000000|30384369.20|
# |     34|  Chris Noonan| Children|   30000000|30384369.20|
# +-------+--------------+---------+-----------+-----------+
# only showing top 10 rows

# %%
### SAVING THE MODEL
#gbt_model.save('gbt_model/')

# %%
### MLEAP SERIALIZATION

#gbt_model.serializeToBundle("jar:file:/Users/mauriciolins/Documents/uaM/2.Projects/MoviesRec/jars/movies_gbt.zip", gbt_model.transform(train_df))
gbt_model.serializeToBundle("jar:file:jars/mleap/xxx.zip",gbt_model.transform(train_df))
# Out:
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/mauriciolins/Documents/uaM/4.Softs/spark/spark-2.4.4-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mauriciolins/Documents/uaM/4.Softs/spark/spark-2.4.4-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/Users/mauriciolins/Documents/uaM/4.Softs/spark/spark-2.4.4-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-14-05592faefd03> in <module>()
#       2
#       3 #gbt_model.serializeToBundle("jar:file:/Users/mauriciolins/Documents/uaM/2.Projects/MoviesRec/jars/movies_gbt.zip", gbt_model.transform(train_df))
# ----> 4 gbt_model.serializeToBundle("jar:file:jars/mleap/xxx.zip",gbt_model.transform(train_df))
#
# ~/opt/anaconda3/envs/opencv/lib/python3.6/site-packages/mleap/pyspark/spark_support.py in serializeToBundle(self, path, dataset)
#      22
#      23 def serializeToBundle(self, path, dataset=None):
# ---> 24     serializer = SimpleSparkSerializer()
#      25     serializer.serializeToBundle(self, path, dataset=dataset)
#      26
#
# ~/opt/anaconda3/envs/opencv/lib/python3.6/site-packages/mleap/pyspark/spark_support.py in __init__(self)
#      37     def __init__(self):
#      38         super(SimpleSparkSerializer, self).__init__()
# ---> 39         self._java_obj = _jvm().ml.combust.mleap.spark.SimpleSparkSerializer()
#      40
#      41     def serializeToBundle(self, transformer, path, dataset):
#
# ~/Documents/uaM/4.Softs/spark/spark-2.4.4-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __getattr__(self, name)
#    1596                 answer[proto.CLASS_FQN_START:], self._gateway_client)
#    1597         else:
# -> 1598             raise Py4JError("{0} does not exist in the JVM".format(new_fqn))
#    1599
#    1600
#
# Py4JError: ml.combust.mleap.spark.SimpleSparkSerializer does not exist in the JVM

# %%
### RANDOM FOREST ##################################################################################################
rf = RandomForestRegressor(featuresCol='features', labelCol='budgetvalue', numTrees=15)

rf_model        = rf.fit(train_df)
rf_pred         = rf_model.transform(test_df)
rf_evaluator    = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='rmse')
rf_rmse         = rf_evaluator.evaluate(rf_pred)
rf_evaluator_r2 = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='r2')
rf_r2           = rf_evaluator_r2.evaluate(rf_pred)

print('### RANDOM FOREST RMSE:')
print(rf_rmse)
print('### RANDOM FOREST r2:')
print(rf_r2)
#rf_pred.withColumn('pred', rf_pred['prediction'].cast(DecimalType(30,2))).show(truncate=False)
# Out:
# ### RANDOM FOREST RMSE:
# 351395990.07634676
# ### RANDOM FOREST r2:
# 0.5404268132355837

# %%
### DECISION TREE ###################################################################################################
dt              = DecisionTreeRegressor(featuresCol='features', labelCol='budgetvalue')
dt_model        = dt.fit(train_df)
dt_pred         = dt_model.transform(test_df)
dt_evaluator    = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='rmse')
dt_rmse         = dt_evaluator.evaluate(dt_pred)
dt_evaluator_r2 = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='r2')
dt_r2           = dt_evaluator_r2.evaluate(dt_pred)

print('### DECISION TREE RMSE:')
print(dt_rmse)
print('### RANDOM FOREST r2:')
print(dt_r2)
# Out:
# ### DECISION TREE RMSE:
# 212444343.14663234
# ### RANDOM FOREST r2:
# 0.8320223803781781

# %%
from pyspark.sql.types import DecimalType
print('DECISION TREE #########################')
dt_pred.select('idmovie','director','genres','budgetvalue', 'prediction')\
        .withColumn('pred', dt_pred['prediction'].cast(DecimalType(38,2)))\
        .drop('prediction')\
        .withColumnRenamed('pred', 'prediction').show(10)
#################################################################################
print('RANDOM FOREST #########################')
rf_pred.select('idmovie','director','genres','budgetvalue', 'prediction')\
        .withColumn('pred', rf_pred['prediction'].cast(DecimalType(38,2)))\
        .drop('prediction')\
        .withColumnRenamed('pred', 'prediction').show(10)
#################################################################################
print('GRADIENT BOOSTED #########################')
gbt_pred.select('idmovie','director','genres','budgetvalue', 'prediction')\
        .withColumn('pred', gbt_pred['prediction'].cast(DecimalType(38,2)))\
        .drop('prediction')\
        .withColumnRenamed('pred', 'prediction').show(10)
# Out:
# DECISION TREE #########################
# +-------+--------------+---------+-----------+-----------+
# |idmovie|      director|   genres|budgetvalue| prediction|
# +-------+--------------+---------+-----------+-----------+
# |      1| John Lasseter|Adventure|   30000000|43101494.29|
# |      1| John Lasseter|Animation|   30000000|43101494.29|
# |      1| John Lasseter|   Comedy|   30000000|43101494.29|
# |      2|  Joe Johnston|Adventure|   65000000|43101494.29|
# |      2|  Joe Johnston|  Fantasy|   65000000|43101494.29|
# |     15|  Renny Harlin|   Action|   98000000|43101494.29|
# |     20|  Joseph Ruben| Thriller|   68000000|43101494.29|
# |     23|Richard Donner|   Action|   50000000|43101494.29|
# |     23|Richard Donner|    Crime|   50000000|43101494.29|
# |     34|  Chris Noonan| Children|   30000000|43101494.29|
# +-------+--------------+---------+-----------+-----------+
# only showing top 10 rows
#
# RANDOM FOREST #########################
# +-------+--------------+---------+-----------+-----------+
# |idmovie|      director|   genres|budgetvalue| prediction|
# +-------+--------------+---------+-----------+-----------+
# |      1| John Lasseter|Adventure|   30000000|44458161.17|
# |      1| John Lasseter|Animation|   30000000|44458161.17|
# |      1| John Lasseter|   Comedy|   30000000|44458161.17|
# |      2|  Joe Johnston|Adventure|   65000000|41858898.22|
# |      2|  Joe Johnston|  Fantasy|   65000000|41858898.22|
# |     15|  Renny Harlin|   Action|   98000000|41858898.22|
# |     20|  Joseph Ruben| Thriller|   68000000|41858898.22|
# |     23|Richard Donner|   Action|   50000000|41858898.22|
# |     23|Richard Donner|    Crime|   50000000|41858898.22|
# |     34|  Chris Noonan| Children|   30000000|44458161.17|
# +-------+--------------+---------+-----------+-----------+
# only showing top 10 rows
#
# GRADIENT BOOSTED #########################
# +-------+--------------+---------+-----------+-----------+
# |idmovie|      director|   genres|budgetvalue| prediction|
# +-------+--------------+---------+-----------+-----------+
# |      1| John Lasseter|Adventure|   30000000|40994034.42|
# |      1| John Lasseter|Animation|   30000000|30384369.20|
# |      1| John Lasseter|   Comedy|   30000000|30384369.20|
# |      2|  Joe Johnston|Adventure|   65000000|40994034.42|
# |      2|  Joe Johnston|  Fantasy|   65000000|30384369.20|
# |     15|  Renny Harlin|   Action|   98000000|38618105.45|
# |     20|  Joseph Ruben| Thriller|   68000000|30384369.20|
# |     23|Richard Donner|   Action|   50000000|38618105.45|
# |     23|Richard Donner|    Crime|   50000000|30384369.20|
# |     34|  Chris Noonan| Children|   30000000|30384369.20|
# +-------+--------------+---------+-----------+-----------+
# only showing top 10 rows

# %%
print(gbt_model.toDebugString)
# Out:
# GBTRegressionModel (uid=GBTRegressor_e32e0291ceb6) with 45 trees
#   Tree 0 (weight 1.0):
#     If (feature 1224 in {0.0})
#      If (feature 683 in {0.0})
#       If (feature 3995 in {0.0})
#        If (feature 3761 in {0.0})
#         If (feature 108 in {0.0})
#          If (feature 2836 in {0.0})
#           Predict: 4.174773514731475E7
#          Else (feature 2836 not in {0.0})
#           Predict: 1.0E10
#         Else (feature 108 not in {0.0})
#          If (feature 0 <= 3.4850000000000003)
#           Predict: 7.6493875E9
#          Else (feature 0 > 3.4850000000000003)
#           Predict: 9525000.0
#        Else (feature 3761 not in {0.0})
#         Predict: 1.9E10
#       Else (feature 3995 not in {0.0})
#        Predict: 2.0E10
#      Else (feature 683 not in {0.0})
#       If (feature 0 <= 3.085)
#        Predict: 5000000.0
#       Else (feature 0 > 3.085)
#        Predict: 3.0E10
#     Else (feature 1224 not in {0.0})
#      Predict: 3.5E10
#   Tree 1 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 803 in {0.0})
#         If (feature 594 in {0.0})
#          If (feature 394 in {0.0})
#           Predict: -1.4425821101854693E7
#          Else (feature 394 not in {0.0})
#           Predict: 1.9662823074831476E9
#         Else (feature 594 not in {0.0})
#          If (feature 0 <= 3.2649999999999997)
#           Predict: 3.7165045297053704E9
#          Else (feature 0 > 3.2649999999999997)
#           Predict: 1.11650452970537E9
#        Else (feature 803 not in {0.0})
#         If (feature 0 <= 4.005)
#          Predict: 9.91650452970537E9
#         Else (feature 0 > 4.005)
#          Predict: -7.609547029462941E7
#       Else (feature 17 not in {0.0})
#        If (feature 0 <= 3.875)
#         If (feature 4421 in {1.0})
#          Predict: -1.54954702946295E7
#         Else (feature 4421 not in {1.0})
#          If (feature 4423 in {1.0})
#           Predict: -1.54954702946295E7
#          Else (feature 4423 not in {1.0})
#           Predict: 7.078790243991083E9
#        Else (feature 0 > 3.875)
#         If (feature 4417 in {0.0})
#          If (feature 4422 in {1.0})
#           Predict: -8.14954702946295E7
#          Else (feature 4422 not in {1.0})
#           Predict: 1.1364445297053716E9
#         Else (feature 4417 not in {0.0})
#          Predict: 4.716504529705372E9
#      Else (feature 2083 not in {0.0})
#       Predict: 9.91650452970537E9
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.435)
#       Predict: -5.949547029462949E7
#      Else (feature 0 > 3.435)
#       If (feature 4424 in {1.0})
#        Predict: -7.74954702946295E7
#       Else (feature 4424 not in {1.0})
#        Predict: 1.991650452970537E10
#   Tree 2 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 803 in {0.0})
#         If (feature 594 in {0.0})
#          If (feature 309 in {0.0})
#           Predict: -1.1761446577202324E7
#          Else (feature 309 not in {0.0})
#           Predict: 1.7386001531257415E9
#         Else (feature 594 not in {0.0})
#          If (feature 0 <= 3.255)
#           Predict: 2.9732036237642965E9
#          Else (feature 0 > 3.255)
#           Predict: 8.932036237642962E8
#        Else (feature 803 not in {0.0})
#         If (feature 0 <= 4.005)
#          Predict: 7.933203623764297E9
#         Else (feature 0 > 4.005)
#          Predict: -6.087637623570362E7
#       Else (feature 17 not in {0.0})
#        If (feature 0 <= 3.885)
#         If (feature 4425 in {1.0})
#          Predict: -1.4312535190928464E9
#         Else (feature 4425 not in {1.0})
#          If (feature 4421 in {1.0})
#           Predict: -1.2396376235703602E7
#          Else (feature 4421 not in {1.0})
#           Predict: 5.865726072743888E9
#        Else (feature 0 > 3.885)
#         If (feature 4417 in {0.0})
#          If (feature 4418 in {1.0})
#           Predict: -2.6278437623570383E8
#          Else (feature 4418 not in {1.0})
#           Predict: 9.190350237642965E8
#         Else (feature 4417 not in {0.0})
#          Predict: 3.7732036237642975E9
#      Else (feature 2083 not in {0.0})
#       Predict: 7.9332036237642975E9
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.435)
#       Predict: -4.759637623570361E7
#      Else (feature 0 > 3.435)
#       If (feature 4424 in {1.0})
#        Predict: -6.19963762357036E7
#       Else (feature 4424 not in {1.0})
#        Predict: 1.5933203623764296E10
#   Tree 3 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 803 in {0.0})
#         If (feature 2955 in {0.0})
#          If (feature 3976 in {0.0})
#           Predict: -8329285.577702984
#          Else (feature 3976 not in {0.0})
#           Predict: 4.92174198324118E9
#         Else (feature 2955 not in {0.0})
#          Predict: 4.92174198324118E9
#        Else (feature 803 not in {0.0})
#         If (feature 0 <= 4.005)
#          Predict: 6.346562899011436E9
#         Else (feature 0 > 4.005)
#          Predict: -4.8701100988562904E7
#       Else (feature 17 not in {0.0})
#        If (feature 0 <= 3.875)
#         If (feature 4423 in {1.0})
#          Predict: -1.1855415907844813E9
#         Else (feature 4423 not in {1.0})
#          If (feature 4425 in {1.0})
#           Predict: -1.1450028152742772E9
#          Else (feature 4425 not in {1.0})
#           Predict: 4.860527213880241E9
#        Else (feature 0 > 3.875)
#         If (feature 4417 in {0.0})
#          If (feature 4422 in {1.0})
#           Predict: -2.4900338098856294E8
#          Else (feature 4422 not in {1.0})
#           Predict: 7.371668130114365E8
#         Else (feature 4417 not in {0.0})
#          Predict: 3.0185628990114365E9
#      Else (feature 2083 not in {0.0})
#       Predict: 6.346562899011436E9
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.435)
#       Predict: -3.807710098856288E7
#      Else (feature 0 > 3.435)
#       If (feature 4424 in {1.0})
#        Predict: -4.959710098856288E7
#       Else (feature 4424 not in {1.0})
#        Predict: 1.2746562899011436E10
#   Tree 4 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 835 in {0.0})
#         If (feature 394 in {0.0})
#          If (feature 803 in {0.0})
#           Predict: -7759173.546160558
#          Else (feature 803 not in {0.0})
#           Predict: 2.0075235992091491E9
#         Else (feature 394 not in {0.0})
#          If (feature 0 <= 3.4450000000000003)
#           Predict: -4.5673378536027795E8
#          Else (feature 0 > 3.4450000000000003)
#           Predict: 2.5939328813063884E9
#        Else (feature 835 not in {0.0})
#         If (feature 4414 in {0.0})
#          Predict: 2.4234078403567224E9
#         Else (feature 4414 not in {0.0})
#          Predict: 2.423407840356722E9
#       Else (feature 17 not in {0.0})
#        If (feature 0 <= 3.875)
#         If (feature 4421 in {1.0})
#          Predict: -9.820225437646112E8
#         Else (feature 4421 not in {1.0})
#          If (feature 4423 in {1.0})
#           Predict: -9.48433272627585E8
#          Else (feature 4423 not in {1.0})
#           Predict: 3.8978532413249354E9
#        Else (feature 0 > 3.875)
#         If (feature 4417 in {0.0})
#          If (feature 4414 in {0.0})
#           Predict: 4.527156045738552E8
#          Else (feature 4414 not in {0.0})
#           Predict: 9.748252564091496E8
#         Else (feature 4417 not in {0.0})
#          Predict: 2.4148503192091484E9
#      Else (feature 2083 not in {0.0})
#       Predict: 5.077250319209148E9
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.4450000000000003)
#       If (feature 4414 in {0.0})
#        Predict: -3.0461680790850304E7
#       Else (feature 4414 not in {0.0})
#        Predict: -3.0461680790850297E7
#      Else (feature 0 > 3.4450000000000003)
#       If (feature 4424 in {1.0})
#        Predict: -3.9677680790850304E7
#       Else (feature 4424 not in {1.0})
#        Predict: 1.0197250319209148E10
#   Tree 5 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 594 in {0.0})
#         If (feature 309 in {0.0})
#          If (feature 1210 in {0.0})
#           Predict: -6684288.26559469
#          Else (feature 1210 not in {0.0})
#           Predict: 2.124959675065956E9
#         Else (feature 309 not in {0.0})
#          If (feature 0 <= 3.3049999999999997)
#           Predict: 2.694887355125366E9
#          Else (feature 0 > 3.3049999999999997)
#           Predict: 9.330827352536622E7
#        Else (feature 594 not in {0.0})
#         If (feature 0 <= 3.255)
#          Predict: 2.3817805908362093E9
#         Else (feature 0 > 3.255)
#          If (feature 4414 in {0.0})
#           Predict: 7.1778059083621E8
#          Else (feature 4414 not in {0.0})
#           Predict: 7.177805908362098E8
#       Else (feature 17 not in {0.0})
#        If (feature 4415 in {0.0})
#         If (feature 4420 in {0.0})
#          If (feature 4424 in {0.0})
#           Predict: 5.272889739441031E8
#          Else (feature 4424 not in {0.0})
#           Predict: 5.575925175317341E9
#         Else (feature 4420 not in {0.0})
#          Predict: 5.575925175317341E9
#        Else (feature 4415 not in {0.0})
#         Predict: 5.575925175317341E9
#      Else (feature 2083 not in {0.0})
#       Predict: 4.061800255367319E9
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.4450000000000003)
#       If (feature 4414 in {0.0})
#        Predict: -2.4369344632680245E7
#       Else (feature 4414 not in {0.0})
#        Predict: -2.4369344632680252E7
#      Else (feature 0 > 3.4450000000000003)
#       If (feature 4424 in {1.0})
#        Predict: -3.1742144632680245E7
#       Else (feature 4424 not in {1.0})
#        Predict: 8.15780025536732E9
#   Tree 6 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 2955 in {0.0})
#         If (feature 3976 in {0.0})
#          If (feature 835 in {0.0})
#           Predict: -4548600.013166668
#          Else (feature 835 not in {0.0})
#           Predict: 1.9400631299384975E9
#         Else (feature 3976 not in {0.0})
#          Predict: 3.9402822789552994E9
#        Else (feature 2955 not in {0.0})
#         Predict: 3.9402822789552994E9
#       Else (feature 17 not in {0.0})
#        If (feature 0 <= 3.865)
#         If (feature 4429 in {1.0})
#          Predict: -4.461532619471479E9
#         Else (feature 4429 not in {1.0})
#          If (feature 4425 in {1.0})
#           Predict: -1.8010306952732296E9
#          Else (feature 4425 not in {1.0})
#           Predict: -8.776401213456991E8
#        Else (feature 0 > 3.865)
#         If (feature 0 <= 3.995)
#          If (feature 4414 in {1.0})
#           Predict: -1.1244758966150105E8
#          Else (feature 4414 not in {1.0})
#           Predict: 3.1336347754919167E9
#         Else (feature 0 > 3.995)
#          If (feature 4414 in {0.0})
#           Predict: 3.629766099504209E8
#          Else (feature 4414 not in {0.0})
#           Predict: 1.461252410338499E9
#      Else (feature 2083 not in {0.0})
#       Predict: 3.2494402042938557E9
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.435)
#       Predict: -1.9495475706144195E7
#      Else (feature 0 > 3.435)
#       If (feature 4424 in {1.0})
#        Predict: -2.5393715706144195E7
#       Else (feature 4424 not in {1.0})
#        Predict: 6.526240204293857E9
#   Tree 7 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 394 in {0.0})
#       If (feature 1496 in {0.0})
#        If (feature 2083 in {0.0})
#         If (feature 17 in {0.0})
#          If (feature 803 in {0.0})
#           Predict: -4546765.156061107
#          Else (feature 803 not in {0.0})
#           Predict: 1.6082654570230713E9
#         Else (feature 17 not in {0.0})
#          If (feature 4417 in {0.0})
#           Predict: 4.6749059260927826E8
#          Else (feature 4417 not in {0.0})
#           Predict: 3.2987837820092764E9
#        Else (feature 2083 not in {0.0})
#         Predict: 2.5995521634350843E9
#       Else (feature 1496 not in {0.0})
#        If (feature 4416 in {0.0})
#         Predict: 2.1283415247217069E9
#        Else (feature 4416 not in {0.0})
#         Predict: 2.1283415247217073E9
#      Else (feature 394 not in {0.0})
#       If (feature 0 <= 3.4850000000000003)
#        Predict: -3.6314045063247013E8
#       Else (feature 0 > 3.4850000000000003)
#        If (feature 0 <= 3.8049999999999997)
#         Predict: 3.010726216034197E9
#        Else (feature 0 > 3.8049999999999997)
#         Predict: 2.1072621603419673E8
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.435)
#       Predict: -1.5596380564915357E7
#      Else (feature 0 > 3.435)
#       If (feature 4424 in {1.0})
#        Predict: -2.0314972564915355E7
#       Else (feature 4424 not in {1.0})
#        Predict: 5.220992163435085E9
#   Tree 8 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 594 in {0.0})
#       If (feature 309 in {0.0})
#        If (feature 1210 in {0.0})
#         If (feature 3976 in {0.0})
#          If (feature 2955 in {0.0})
#           Predict: -3135585.63845808
#          Else (feature 2955 not in {0.0})
#           Predict: 3.15313517619545E9
#         Else (feature 3976 not in {0.0})
#          Predict: 3.15313517619545E9
#        Else (feature 1210 not in {0.0})
#         Predict: 1.701786813086609E9
#       Else (feature 309 not in {0.0})
#        If (feature 0 <= 3.3049999999999997)
#         If (feature 0 <= 2.835)
#          Predict: -6.622710428658619E8
#         Else (feature 0 > 2.835)
#          Predict: 4.037728957134138E9
#        Else (feature 0 > 3.3049999999999997)
#         If (feature 0 <= 3.495)
#          Predict: -4.0590293054586184E8
#         Else (feature 0 > 3.495)
#          Predict: 3.980447734541381E8
#      Else (feature 594 not in {0.0})
#       If (feature 0 <= 3.255)
#        Predict: 1.9072435457028134E9
#       Else (feature 0 > 3.255)
#        If (feature 4414 in {0.0})
#         Predict: 5.760435457028135E8
#        Else (feature 4414 not in {0.0})
#         Predict: 5.760435457028134E8
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.4450000000000003)
#       Predict: -1.2477104451932287E7
#      Else (feature 0 > 3.4450000000000003)
#       If (feature 4424 in {1.0})
#        Predict: -1.6251978051932283E7
#       Else (feature 4424 not in {1.0})
#        Predict: 4.176793730748068E9
#   Tree 9 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 835 in {0.0})
#       If (feature 394 in {0.0})
#        If (feature 114 in {0.0})
#         If (feature 1496 in {0.0})
#          If (feature 2083 in {0.0})
#           Predict: -3147644.480633907
#          Else (feature 2083 not in {0.0})
#           Predict: 2.0802688478757591E9
#         Else (feature 1496 not in {0.0})
#          Predict: 1.703300336905057E9
#        Else (feature 114 not in {0.0})
#         If (feature 0 <= 2.455)
#          Predict: 2.2287427228806105E9
#         Else (feature 0 > 2.455)
#          If (feature 0 <= 2.885)
#           Predict: -5.0857277119389296E7
#          Else (feature 0 > 2.885)
#           Predict: 3.662427228806107E8
#       Else (feature 394 not in {0.0})
#        If (feature 0 <= 3.4850000000000003)
#         Predict: -2.8988524337828445E8
#        Else (feature 0 > 3.4850000000000003)
#         If (feature 0 <= 3.795)
#          Predict: 2.4092080899550486E9
#         Else (feature 0 > 3.795)
#          Predict: 1.692080899550495E8
#      Else (feature 835 not in {0.0})
#       Predict: 1.5535869741097012E9
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.435)
#       Predict: -9981683.561545832
#      Else (feature 0 > 3.435)
#       If (feature 4424 in {1.0})
#        Predict: -1.3001582441545825E7
#       Else (feature 4424 not in {1.0})
#        Predict: 3.3414349845984535E9
#   Tree 10 (weight 0.1):
#     If (feature 374 in {0.0})
#      If (feature 17 in {0.0})
#       If (feature 803 in {0.0})
#        If (feature 509 in {0.0})
#         If (feature 594 in {0.0})
#          If (feature 309 in {0.0})
#           Predict: -3717946.543984874
#          Else (feature 309 not in {0.0})
#           Predict: 8.943073884914376E8
#         Else (feature 594 not in {0.0})
#          If (feature 0 <= 3.2649999999999997)
#           Predict: 1.5264243654583774E9
#          Else (feature 0 > 3.2649999999999997)
#           Predict: 4.6146436545837754E8
#        Else (feature 509 not in {0.0})
#         If (feature 0 <= 2.045)
#          Predict: 1.7893722517767375E9
#         Else (feature 0 > 2.045)
#          If (feature 0 <= 2.3049999999999997)
#           Predict: 8.293722517767375E8
#          Else (feature 0 > 2.3049999999999997)
#           Predict: 4.4270558511007077E8
#       Else (feature 803 not in {0.0})
#        If (feature 0 <= 4.005)
#         Predict: 4.357595731642275E9
#        Else (feature 0 > 4.005)
#         If (feature 4414 in {0.0})
#          Predict: -7.586154683577238E8
#         Else (feature 4414 not in {0.0})
#          Predict: -7.58615468357724E8
#      Else (feature 17 not in {0.0})
#       If (feature 0 <= 3.885)
#        If (feature 4425 in {1.0})
#         Predict: -1.533066028716621E9
#        Else (feature 4425 not in {1.0})
#         If (feature 4421 in {1.0})
#          Predict: -8.077892780294069E8
#         Else (feature 4421 not in {1.0})
#          If (feature 4423 in {1.0})
#           Predict: -7.809178611197861E8
#          Else (feature 4423 not in {1.0})
#           Predict: 2.7500978063135552E9
#       Else (feature 0 > 3.885)
#        If (feature 0 <= 4.005)
#         If (feature 4429 in {1.0})
#          Predict: -7.26994086890863E8
#         Else (feature 4429 not in {1.0})
#          If (feature 4414 in {1.0})
#           Predict: -1.8219954422723806E8
#          Else (feature 4414 not in {1.0})
#           Predict: 4.300591310913706E7
#        Else (feature 0 > 4.005)
#         If (feature 4414 in {0.0})
#          If (feature 4417 in {0.0})
#           Predict: 9.360796898886503E7
#          Else (feature 4417 not in {0.0})
#           Predict: 1.0953270282103777E9
#         Else (feature 4414 not in {0.0})
#          Predict: 1.076760455772762E9
#     Else (feature 374 not in {0.0})
#      If (feature 0 <= 3.4450000000000003)
#       Predict: -7985346.849236664
#      Else (feature 0 > 3.4450000000000003)
#       If (feature 4424 in {1.0})
#        Predict: -1.040126595323666E7
#       Else (feature 4424 not in {1.0})
#        Predict: 2.6731479876787643E9
#   Tree 11 (weight 0.1):
#     If (feature 1210 in {0.0})
#      If (feature 2920 in {0.0})
#       If (feature 3909 in {0.0})
#        If (feature 697 in {0.0})
#         If (feature 2955 in {0.0})
#          If (feature 3976 in {0.0})
#           Predict: -1554167.9931253775
#          Else (feature 3976 not in {0.0})
#           Predict: 2.5238812591612816E9
#         Else (feature 2955 not in {0.0})
#          Predict: 2.5238812591612816E9
#        Else (feature 697 not in {0.0})
#         If (feature 0 <= 3.505)
#          If (feature 0 <= 3.335)
#           Predict: 5.011584108553445E7
#          Else (feature 0 > 3.335)
#           Predict: 6.101158410855345E8
#         Else (feature 0 > 3.505)
#          Predict: 2.4301158410855346E9
#       Else (feature 3909 not in {0.0})
#        Predict: 2.530115841085535E9
#      Else (feature 2920 not in {0.0})
#       Predict: 1.8361158410855346E9
#     Else (feature 1210 not in {0.0})
#      Predict: 1.362802568674211E9
#   Tree 12 (weight 0.1):
#     If (feature 835 in {0.0})
#      If (feature 2765 in {0.0})
#       If (feature 394 in {0.0})
#        If (feature 2935 in {0.0})
#         If (feature 114 in {0.0})
#          If (feature 374 in {0.0})
#           Predict: -2308630.9024003115
#          Else (feature 374 not in {0.0})
#           Predict: 9.128921657740936E8
#         Else (feature 114 not in {0.0})
#          If (feature 0 <= 2.455)
#           Predict: 1.7840486012119107E9
#          Else (feature 0 > 2.455)
#           Predict: 2.0304496484827423E8
#        Else (feature 2935 not in {0.0})
#         Predict: 1.7184266746841595E9
#       Else (feature 394 not in {0.0})
#        If (feature 0 <= 3.4850000000000003)
#         If (feature 4414 in {0.0})
#          Predict: -2.3085377179520553E8
#         Else (feature 4414 not in {0.0})
#          Predict: -2.3085377179520547E8
#        Else (feature 0 > 3.4850000000000003)
#         If (feature 0 <= 3.795)
#          Predict: 1.9284208948714612E9
#         Else (feature 0 > 3.795)
#          Predict: 1.364208948714614E8
#      Else (feature 2765 not in {0.0})
#       Predict: 2.47042667468416E9
#     Else (feature 835 not in {0.0})
#      Predict: 1.243924002195183E9
#   Tree 13 (weight 0.1):
#     If (feature 1496 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 803 in {0.0})
#         If (feature 1678 in {0.0})
#          If (feature 556 in {0.0})
#           Predict: -2360307.7525588404
#          Else (feature 556 not in {0.0})
#           Predict: 1.0288884008646393E9
#         Else (feature 1678 not in {0.0})
#          Predict: 1.3308884008646393E9
#        Else (feature 803 not in {0.0})
#         If (feature 0 <= 4.005)
#          Predict: 3.486849145092925E9
#         Else (feature 0 > 4.005)
#          Predict: -6.06119814907074E8
#       Else (feature 17 not in {0.0})
#        If (feature 4415 in {0.0})
#         If (feature 4420 in {0.0})
#          If (feature 4424 in {0.0})
#           Predict: 1.2059316717219634E8
#          Else (feature 4424 not in {0.0})
#           Predict: 3.1925247111738467E9
#         Else (feature 4420 not in {0.0})
#          Predict: 3.1925247111738462E9
#        Else (feature 4415 not in {0.0})
#         Predict: 3.192524711173847E9
#      Else (feature 2083 not in {0.0})
#       Predict: 1.6657312273885098E9
#     Else (feature 1496 not in {0.0})
#      Predict: 1.3641564186119478E9
#   Tree 14 (weight 0.1):
#     If (feature 509 in {0.0})
#      If (feature 594 in {0.0})
#       If (feature 309 in {0.0})
#        If (feature 1210 in {0.0})
#         If (feature 928 in {0.0})
#          If (feature 1250 in {0.0})
#           Predict: -2127192.660269252
#          Else (feature 1250 not in {0.0})
#           Predict: 1.4888604624151516E9
#         Else (feature 928 not in {0.0})
#          If (feature 0 <= 3.025)
#           Predict: 1.9313604624151514E9
#          Else (feature 0 > 3.025)
#           Predict: 2.913604624151514E8
#        Else (feature 1210 not in {0.0})
#         Predict: 1.0911758426703606E9
#       Else (feature 309 not in {0.0})
#        If (feature 0 <= 3.3049999999999997)
#         If (feature 0 <= 2.835)
#          Predict: -7.068041617652335E8
#         Else (feature 0 > 2.835)
#          If (feature 4417 in {0.0})
#           Predict: 3.053195838234767E9
#          Else (feature 4417 not in {0.0})
#           Predict: 3.053195838234766E9
#        Else (feature 0 > 3.3049999999999997)
#         If (feature 0 <= 3.4850000000000003)
#          Predict: -5.0170967190923345E8
#         Else (feature 0 > 3.4850000000000003)
#          Predict: 1.414484912907666E8
#      Else (feature 594 not in {0.0})
#       If (feature 0 <= 3.255)
#        Predict: 1.222384113696319E9
#       Else (feature 0 > 3.255)
#        Predict: 3.704161136963189E8
#     Else (feature 509 not in {0.0})
#      If (feature 0 <= 2.075)
#       Predict: 1.4327424227510068E9
#      Else (feature 0 > 2.075)
#       If (feature 0 <= 2.325)
#        Predict: 6.647424227510068E8
#       Else (feature 0 > 2.325)
#        If (feature 0 <= 3.025)
#         Predict: 2.120757560843402E8
#        Else (feature 0 > 3.025)
#         Predict: 6.420757560843402E8
#   Tree 15 (weight 0.1):
#     If (feature 2920 in {0.0})
#      If (feature 3909 in {0.0})
#       If (feature 2342 in {0.0})
#        If (feature 3071 in {0.0})
#         If (feature 697 in {0.0})
#          If (feature 2955 in {0.0})
#           Predict: -1199828.506490641
#          Else (feature 2955 not in {0.0})
#           Predict: 2.0204642335920715E9
#         Else (feature 697 not in {0.0})
#          If (feature 0 <= 3.5149999999999997)
#           Predict: 2.6545189913147324E8
#          Else (feature 0 > 3.5149999999999997)
#           Predict: 1.945451899131473E9
#        Else (feature 3071 not in {0.0})
#         Predict: 1.4317859009472055E9
#       Else (feature 2342 not in {0.0})
#        Predict: 1.4317859009472055E9
#      Else (feature 3909 not in {0.0})
#       Predict: 2.025451899131473E9
#     Else (feature 2920 not in {0.0})
#      Predict: 1.470251899131473E9
#   Tree 16 (weight 0.1):
#     If (feature 3976 in {0.0})
#      If (feature 593 in {0.0})
#       If (feature 835 in {0.0})
#        If (feature 2765 in {0.0})
#         If (feature 394 in {0.0})
#          If (feature 2935 in {0.0})
#           Predict: -1429776.097743786
#          Else (feature 2935 not in {0.0})
#           Predict: 1.3758788055311909E9
#         Else (feature 394 not in {0.0})
#          If (feature 0 <= 3.4850000000000003)
#           Predict: -1.835455516523007E8
#          Else (feature 0 > 3.4850000000000003)
#           Predict: 1.0660075150143665E9
#        Else (feature 2765 not in {0.0})
#         Predict: 1.9774788055311909E9
#       Else (feature 835 not in {0.0})
#        Predict: 9.962766675400105E8
#      Else (feature 593 not in {0.0})
#       If (feature 0 <= 2.7649999999999997)
#        Predict: 1.1320258666485033E9
#       Else (feature 0 > 2.7649999999999997)
#        Predict: 5.320258666485033E8
#     Else (feature 3976 not in {0.0})
#      Predict: 2.0207041992933702E9
#   Tree 17 (weight 0.1):
#     If (feature 114 in {0.0})
#      If (feature 374 in {0.0})
#       If (feature 1496 in {0.0})
#        If (feature 2083 in {0.0})
#         If (feature 2058 in {0.0})
#          If (feature 17 in {0.0})
#           Predict: -2155649.7349063302
#          Else (feature 17 not in {0.0})
#           Predict: 3.3525285143594694E8
#         Else (feature 2058 not in {0.0})
#          Predict: 1.332311821868052E9
#        Else (feature 2083 not in {0.0})
#         Predict: 1.3335363413637085E9
#       Else (feature 1496 not in {0.0})
#        Predict: 1.0922764943424594E9
#      Else (feature 374 not in {0.0})
#       If (feature 0 <= 3.435)
#        If (feature 4414 in {0.0})
#         Predict: -1.8723245603217047E8
#        Else (feature 4414 not in {0.0})
#         Predict: -1.8723245603217041E8
#       Else (feature 0 > 3.435)
#        If (feature 4424 in {1.0})
#         Predict: -1.8916519131537047E8
#        Else (feature 4424 not in {1.0})
#         Predict: 1.957674211590229E9
#     Else (feature 114 not in {0.0})
#      If (feature 0 <= 2.455)
#       Predict: 1.428662301972941E9
#      Else (feature 0 > 2.455)
#       If (feature 0 <= 2.885)
#        Predict: -7.881697075433174E7
#       Else (feature 0 > 2.885)
#        If (feature 0 <= 3.025)
#         Predict: 5.1736302924566823E8
#        Else (feature 0 > 3.025)
#         Predict: 9.736302924566822E7
#   Tree 18 (weight 0.1):
#     If (feature 1374 in {0.0})
#      If (feature 997 in {0.0})
#       If (feature 803 in {0.0})
#        If (feature 1678 in {0.0})
#         If (feature 556 in {0.0})
#          If (feature 223 in {0.0})
#           Predict: -1709101.4068132213
#          Else (feature 223 not in {0.0})
#           Predict: 5.787429518150333E8
#         Else (feature 556 not in {0.0})
#          If (feature 0 <= 2.315)
#           Predict: 3.3264932100915937E9
#          Else (feature 0 > 2.315)
#           Predict: 1.9899321009159374E8
#        Else (feature 1678 not in {0.0})
#         Predict: 1.0660932100915934E9
#       Else (feature 803 not in {0.0})
#        If (feature 0 <= 4.005)
#         Predict: 2.790861805474222E9
#        Else (feature 0 > 4.005)
#         If (feature 4414 in {0.0})
#          Predict: -4.835133625257772E8
#         Else (feature 4414 not in {0.0})
#          Predict: -4.835133625257771E8
#      Else (feature 997 not in {0.0})
#       Predict: 8.327429518150333E8
#     Else (feature 1374 not in {0.0})
#      Predict: 9.327429518150333E8
#   Tree 19 (weight 0.1):
#     If (feature 509 in {0.0})
#      If (feature 594 in {0.0})
#       If (feature 309 in {0.0})
#        If (feature 902 in {0.0})
#         If (feature 659 in {0.0})
#          If (feature 1406 in {0.0})
#           Predict: -1856245.6867883173
#          Else (feature 1406 not in {0.0})
#           Predict: 1.0330847720963961E9
#         Else (feature 659 not in {0.0})
#          If (feature 4418 in {0.0})
#           Predict: 4.9975163876306266E8
#          Else (feature 4418 not in {0.0})
#           Predict: 1.7330847720963964E9
#        Else (feature 902 not in {0.0})
#         If (feature 0 <= 3.255)
#          Predict: 9.33084772096396E8
#         Else (feature 0 > 3.255)
#          Predict: 6.33084772096396E8
#       Else (feature 309 not in {0.0})
#        If (feature 0 <= 3.295)
#         If (feature 0 <= 2.835)
#          Predict: -5.641444582629961E8
#         Else (feature 0 > 2.835)
#          Predict: 2.4438555417370043E9
#        Else (feature 0 > 3.295)
#         If (feature 0 <= 3.5149999999999997)
#          Predict: -4.00068866378196E8
#         Else (feature 0 > 3.5149999999999997)
#          Predict: 1.1445766418180406E8
#      Else (feature 594 not in {0.0})
#       If (feature 0 <= 3.255)
#        Predict: 9.79206162106246E8
#       Else (feature 0 > 3.255)
#        Predict: 2.97631762106246E8
#     Else (feature 509 not in {0.0})
#      If (feature 0 <= 2.025)
#       Predict: 1.147492809349996E9
#      Else (feature 0 > 2.025)
#       If (feature 0 <= 2.435)
#        Predict: 5.3309280934999627E8
#       Else (feature 0 > 2.435)
#        If (feature 0 <= 3.025)
#         Predict: 1.7095947601666296E8
#        Else (feature 0 > 3.025)
#         Predict: 5.1495947601666296E8
#   Tree 20 (weight 0.1):
#     If (feature 4431 in {0.0})
#      If (feature 1210 in {0.0})
#       If (feature 831 in {0.0})
#        If (feature 928 in {0.0})
#         If (feature 1250 in {0.0})
#          If (feature 2920 in {0.0})
#           Predict: -2251836.596412927
#          Else (feature 2920 not in {0.0})
#           Predict: 1.1776316738904285E9
#         Else (feature 1250 not in {0.0})
#          If (feature 0 <= 1.76)
#           Predict: 2.7352584902186694E9
#          Else (feature 0 > 1.76)
#           Predict: -3.497415097813306E8
#        Else (feature 928 not in {0.0})
#         If (feature 0 <= 3.025)
#          Predict: 1.5467584902186694E9
#         Else (feature 0 > 3.025)
#          Predict: 2.3475849021866956E8
#       Else (feature 831 not in {0.0})
#        If (feature 0 <= 2.075)
#         Predict: 1.1334560212337537E9
#        Else (feature 0 > 2.075)
#         Predict: 5.334560212337537E8
#      Else (feature 1210 not in {0.0})
#       Predict: 8.746107944228368E8
#     Else (feature 4431 not in {0.0})
#      If (feature 12 in {0.0})
#       If (feature 42 in {0.0})
#        If (feature 0 <= 3.125)
#         If (feature 1464 in {1.0})
#          Predict: -6.0543978766246326E7
#         Else (feature 1464 not in {1.0})
#          If (feature 834 in {1.0})
#           Predict: -4.9543978766246326E7
#          Else (feature 834 not in {1.0})
#           Predict: 1.2416713234486479E8
#        Else (feature 0 > 3.125)
#         If (feature 2458 in {1.0})
#          Predict: -5.8543978766246326E7
#         Else (feature 2458 not in {1.0})
#          If (feature 260 in {1.0})
#           Predict: -3.0543978766246326E7
#          Else (feature 260 not in {1.0})
#           Predict: 2.0576636606133962E8
#       Else (feature 42 not in {0.0})
#        If (feature 0 <= 2.9450000000000003)
#         Predict: 4.734560212337537E8
#        Else (feature 0 > 2.9450000000000003)
#         Predict: 3.234560212337537E8
#      Else (feature 12 not in {0.0})
#       If (feature 0 <= 2.9450000000000003)
#        Predict: 4.064560212337537E8
#       Else (feature 0 > 2.9450000000000003)
#        Predict: 3.334560212337537E8
#   Tree 21 (weight 0.1):
#     If (feature 842 in {0.0})
#      If (feature 468 in {0.0})
#       If (feature 1234 in {0.0})
#        If (feature 697 in {0.0})
#         If (feature 2342 in {0.0})
#          If (feature 3071 in {0.0})
#           Predict: -1259846.3135540427
#          Else (feature 3071 not in {0.0})
#           Predict: 1.1473092426622972E9
#         Else (feature 2342 not in {0.0})
#          Predict: 1.147309242662297E9
#        Else (feature 697 not in {0.0})
#         If (feature 0 <= 3.525)
#          If (feature 4414 in {1.0})
#           Predict: 5.4242041209711514E7
#          Else (feature 4414 not in {1.0})
#           Predict: 3.7424204120971155E8
#         Else (feature 0 > 3.525)
#          Predict: 1.5582420412097113E9
#       Else (feature 1234 not in {0.0})
#        Predict: 1.6339063885530357E9
#      Else (feature 468 not in {0.0})
#       If (feature 0 <= 3.075)
#        Predict: 2.939063885530363E8
#       Else (feature 0 > 3.075)
#        If (feature 0 <= 3.4450000000000003)
#         Predict: 9.339063885530362E8
#        Else (feature 0 > 3.4450000000000003)
#         Predict: 6.339063885530362E8
#     Else (feature 842 not in {0.0})
#      If (feature 0 <= 1.53)
#       Predict: 8.339063885530362E8
#      Else (feature 0 > 1.53)
#       Predict: 6.739063885530362E8
#   Tree 22 (weight 0.1):
#     If (feature 3909 in {0.0})
#      If (feature 2955 in {0.0})
#       If (feature 3976 in {0.0})
#        If (feature 1835 in {0.0})
#         If (feature 817 in {0.0})
#          If (feature 593 in {0.0})
#           Predict: -981855.0862547186
#          Else (feature 593 not in {0.0})
#           Predict: 7.154672292664979E8
#         Else (feature 817 not in {0.0})
#          If (feature 0 <= 3.205)
#           Predict: 9.341583578157469E8
#          Else (feature 0 > 3.205)
#           Predict: 4.1415835781574726E8
#        Else (feature 1835 not in {0.0})
#         If (feature 4416 in {0.0})
#          Predict: 9.34158357815747E8
#         Else (feature 4416 not in {0.0})
#          Predict: 9.341583578157468E8
#       Else (feature 3976 not in {0.0})
#        Predict: 1.618409895382391E9
#      Else (feature 2955 not in {0.0})
#       Predict: 1.6185038780409012E9
#     Else (feature 3909 not in {0.0})
#      Predict: 1.6224940104724221E9
#   Tree 23 (weight 0.1):
#     If (feature 835 in {0.0})
#      If (feature 2765 in {0.0})
#       If (feature 394 in {0.0})
#        If (feature 114 in {0.0})
#         If (feature 2935 in {0.0})
#          If (feature 374 in {0.0})
#           Predict: -1484854.2113809313
#          Else (feature 374 not in {0.0})
#           Predict: 5.870014999161131E8
#         Else (feature 2935 not in {0.0})
#          Predict: 1.1027459513898993E9
#        Else (feature 114 not in {0.0})
#         If (feature 0 <= 2.435)
#          Predict: 1.1445416185963173E9
#         Else (feature 0 > 2.435)
#          If (feature 0 <= 2.885)
#           Predict: -6.144179958550075E7
#          Else (feature 0 > 2.885)
#           Predict: 2.0550220041449922E8
#       Else (feature 394 not in {0.0})
#        If (feature 0 <= 3.495)
#         If (feature 4414 in {0.0})
#          Predict: -1.4479353435689464E8
#         Else (feature 4414 not in {0.0})
#          Predict: -1.4479353435689467E8
#        Else (feature 0 > 3.495)
#         If (feature 0 <= 3.8049999999999997)
#          Predict: 1.3327155856431055E9
#         Else (feature 0 > 3.8049999999999997)
#          Predict: -1.008844143568945E8
#      Else (feature 2765 not in {0.0})
#       Predict: 1.5840259513898988E9
#     Else (feature 835 not in {0.0})
#      If (feature 4414 in {0.0})
#       Predict: 7.990642409969543E8
#      Else (feature 4414 not in {0.0})
#       Predict: 7.990642409969544E8
#   Tree 24 (weight 0.1):
#     If (feature 1496 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 2058 in {0.0})
#        If (feature 17 in {0.0})
#         If (feature 1374 in {0.0})
#          If (feature 997 in {0.0})
#           Predict: -1470524.4968454246
#          Else (feature 997 not in {0.0})
#           Predict: 6.677612890309051E8
#         Else (feature 1374 not in {0.0})
#          Predict: 7.477612890309048E8
#        Else (feature 17 not in {0.0})
#         If (feature 0 <= 3.855)
#          If (feature 4429 in {1.0})
#           Predict: -4.299023665967314E9
#          Else (feature 4429 not in {1.0})
#           Predict: -9.200093813935992E8
#         Else (feature 0 > 3.855)
#          If (feature 0 <= 3.9850000000000003)
#           Predict: 1.8126695731345513E9
#          Else (feature 0 > 3.9850000000000003)
#           Predict: 1.3719033487425965E8
#       Else (feature 2058 not in {0.0})
#        Predict: 1.0677582053546826E9
#      Else (feature 2083 not in {0.0})
#       Predict: 1.0687378209512062E9
#     Else (feature 1496 not in {0.0})
#      If (feature 4417 in {0.0})
#       Predict: 8.757299433342079E8
#      Else (feature 4417 not in {0.0})
#       Predict: 8.757299433342078E8
#   Tree 25 (weight 0.1):
#     If (feature 803 in {0.0})
#      If (feature 1678 in {0.0})
#       If (feature 556 in {0.0})
#        If (feature 223 in {0.0})
#         If (feature 509 in {0.0})
#          If (feature 309 in {0.0})
#           Predict: -1518763.5833946401
#          Else (feature 309 not in {0.0})
#           Predict: 4.6121082081881297E8
#         Else (feature 509 not in {0.0})
#          If (feature 0 <= 2.0949999999999998)
#           Predict: 9.194840308208865E8
#          Else (feature 0 > 2.0949999999999998)
#           Predict: 2.794840308208866E8
#        Else (feature 223 not in {0.0})
#         If (feature 4432 in {0.0})
#          If (feature 0 <= 3.085)
#           Predict: 8.18855393930274E8
#          Else (feature 0 > 3.085)
#           Predict: 1.1218872726360734E8
#         Else (feature 4432 not in {0.0})
#          Predict: 1.518855393930274E9
#       Else (feature 556 not in {0.0})
#        If (feature 0 <= 2.335)
#         Predict: 2.6630556005515223E9
#        Else (feature 0 > 2.335)
#         If (feature 0 <= 2.835)
#          Predict: 2.885556005515222E8
#         Else (feature 0 > 2.835)
#          Predict: -2.2144439944847775E8
#      Else (feature 1678 not in {0.0})
#       Predict: 8.547356005515223E8
#     Else (feature 803 not in {0.0})
#      If (feature 0 <= 3.9850000000000003)
#       Predict: 2.234550476857625E9
#      Else (feature 0 > 3.9850000000000003)
#       Predict: -3.8494965754237443E8
#   Tree 26 (weight 0.1):
#     If (feature 594 in {0.0})
#      If (feature 902 in {0.0})
#       If (feature 659 in {0.0})
#        If (feature 1406 in {0.0})
#         If (feature 4431 in {0.0})
#          If (feature 1210 in {0.0})
#           Predict: -2049493.0798691784
#          Else (feature 1210 not in {0.0})
#           Predict: 7.010318042765551E8
#         Else (feature 4431 not in {0.0})
#          If (feature 12 in {0.0})
#           Predict: 1.4098886484616798E8
#          Else (feature 12 not in {0.0})
#           Predict: 3.0704131905862236E8
#        Else (feature 1406 not in {0.0})
#         Predict: 8.282613537346854E8
#       Else (feature 659 not in {0.0})
#        If (feature 4418 in {0.0})
#         If (feature 4419 in {1.0})
#          Predict: -1.6507161959864798E8
#         Else (feature 4419 not in {1.0})
#          If (feature 4416 in {1.0})
#           Predict: 2.3492818040135205E8
#          Else (feature 4416 not in {1.0})
#           Predict: 7.01594780401352E8
#        Else (feature 4418 not in {0.0})
#         Predict: 1.3882613537346854E9
#      Else (feature 902 not in {0.0})
#       If (feature 0 <= 3.255)
#        If (feature 4416 in {0.0})
#         Predict: 7.482613537346853E8
#        Else (feature 4416 not in {0.0})
#         Predict: 7.482613537346852E8
#       Else (feature 0 > 3.255)
#        Predict: 5.0826135373468536E8
#     Else (feature 594 not in {0.0})
#      If (feature 0 <= 3.255)
#       Predict: 7.851584657425652E8
#      Else (feature 0 > 3.255)
#       Predict: 2.398989457425653E8
#   Tree 27 (weight 0.1):
#     If (feature 831 in {0.0})
#      If (feature 4421 in {0.0})
#       If (feature 17 in {0.0})
#        If (feature 928 in {0.0})
#         If (feature 3767 in {0.0})
#          If (feature 1250 in {0.0})
#           Predict: -3738275.5037927576
#          Else (feature 1250 not in {0.0})
#           Predict: 9.559598595291939E8
#         Else (feature 3767 not in {0.0})
#          Predict: 1.3556594559072952E9
#        Else (feature 928 not in {0.0})
#         If (feature 0 <= 3.035)
#          Predict: 1.2391598595291953E9
#         Else (feature 0 > 3.035)
#          Predict: 1.8955985952919546E8
#       Else (feature 17 not in {0.0})
#        If (feature 0 <= 3.875)
#         If (feature 4425 in {1.0})
#          Predict: -1.1292738319913058E9
#         Else (feature 4425 not in {1.0})
#          If (feature 4423 in {1.0})
#           Predict: -5.275552979138384E8
#          Else (feature 4423 not in {1.0})
#           Predict: 1.6472513986971023E9
#        Else (feature 0 > 3.875)
#         If (feature 0 <= 4.005)
#          If (feature 4414 in {0.0})
#           Predict: -8.634041456103004E8
#          Else (feature 4414 not in {0.0})
#           Predict: -4.2756851147940075E8
#         Else (feature 0 > 4.005)
#          If (feature 4418 in {1.0})
#           Predict: -8.514811198519179E8
#          Else (feature 4418 not in {1.0})
#           Predict: 1.8432604459355983E8
#      Else (feature 4421 not in {0.0})
#       If (feature 309 in {0.0})
#        If (feature 1406 in {0.0})
#         If (feature 26 in {0.0})
#          If (feature 36 in {0.0})
#           Predict: 4.3872217763290964E7
#          Else (feature 36 not in {0.0})
#           Predict: 4.606594559072952E8
#         Else (feature 26 not in {0.0})
#          If (feature 0 <= 3.745)
#           Predict: 3.6665945590729606E8
#          Else (feature 0 > 3.745)
#           Predict: 1.2265945590729606E8
#        Else (feature 1406 not in {0.0})
#         Predict: 6.626090829877472E8
#       Else (feature 309 not in {0.0})
#        If (feature 0 <= 3.295)
#         Predict: 1.8647419511827044E9
#        Else (feature 0 > 3.295)
#         Predict: 1223649.1385440826
#     Else (feature 831 not in {0.0})
#      If (feature 0 <= 2.075)
#       Predict: 9.085178843412627E8
#      Else (feature 0 > 2.075)
#       If (feature 4414 in {0.0})
#        Predict: 4.285178843412627E8
#       Else (feature 4414 not in {0.0})
#        Predict: 4.285178843412626E8
#   Tree 28 (weight 0.1):
#     If (feature 3520 in {0.0})
#      If (feature 2920 in {0.0})
#       If (feature 842 in {0.0})
#        If (feature 468 in {0.0})
#         If (feature 563 in {0.0})
#          If (feature 808 in {0.0})
#           Predict: -1072019.4791108486
#          Else (feature 808 not in {0.0})
#           Predict: 6.564071110080547E8
#         Else (feature 563 not in {0.0})
#          If (feature 4418 in {1.0})
#           Predict: 3.364071110080546E8
#          Else (feature 4418 not in {1.0})
#           Predict: 5.764071110080546E8
#        Else (feature 468 not in {0.0})
#         If (feature 0 <= 3.085)
#          Predict: 2.373738640347365E8
#         Else (feature 0 > 3.085)
#          If (feature 0 <= 3.4450000000000003)
#           Predict: 7.493738640347365E8
#          Else (feature 0 > 3.4450000000000003)
#           Predict: 5.093738640347364E8
#       Else (feature 842 not in {0.0})
#        If (feature 0 <= 1.76)
#         Predict: 6.693738640347365E8
#        Else (feature 0 > 1.76)
#         If (feature 4414 in {0.0})
#          Predict: 5.413738640347365E8
#         Else (feature 4414 not in {0.0})
#          Predict: 5.413738640347364E8
#      Else (feature 2920 not in {0.0})
#       Predict: 9.446060615673617E8
#     Else (feature 3520 not in {0.0})
#      Predict: 1.3364071110080545E9
#   Tree 29 (weight 0.1):
#     If (feature 1234 in {0.0})
#      If (feature 697 in {0.0})
#       If (feature 2342 in {0.0})
#        If (feature 3071 in {0.0})
#         If (feature 3909 in {0.0})
#          If (feature 1835 in {0.0})
#           Predict: -796944.4830917428
#          Else (feature 1835 not in {0.0})
#           Predict: 7.495934723234762E8
#         Else (feature 3909 not in {0.0})
#          Predict: 1.3002619944488163E9
#        Else (feature 3071 not in {0.0})
#         Predict: 9.20310551217967E8
#       Else (feature 2342 not in {0.0})
#        Predict: 9.20310551217967E8
#      Else (feature 697 not in {0.0})
#       If (feature 0 <= 3.525)
#        If (feature 4414 in {1.0})
#         If (feature 0 <= 3.3449999999999998)
#          Predict: -1.8143209944101095E7
#         Else (feature 0 > 3.3449999999999998)
#          Predict: 1.098567900558989E8
#        Else (feature 4414 not in {1.0})
#         Predict: 3.018567900558989E8
#       Else (feature 0 > 3.525)
#        Predict: 1.249056790055899E9
#     Else (feature 1234 not in {0.0})
#      Predict: 1.3095882679305587E9
#   Tree 30 (weight 0.1):
#     If (feature 2955 in {0.0})
#      If (feature 3976 in {0.0})
#       If (feature 817 in {0.0})
#        If (feature 593 in {0.0})
#         If (feature 835 in {0.0})
#          If (feature 2765 in {0.0})
#           Predict: -807381.2633071132
#          Else (feature 2765 not in {0.0})
#           Predict: 1.2693499652371407E9
#         Else (feature 835 not in {0.0})
#          Predict: 6.413805969227843E8
#        Else (feature 593 not in {0.0})
#         If (feature 0 <= 2.775)
#          If (feature 4414 in {0.0})
#           Predict: 7.667999583806951E8
#          Else (feature 4414 not in {0.0})
#           Predict: 7.667999583806949E8
#         Else (feature 0 > 2.775)
#          Predict: 2.867999583806951E8
#       Else (feature 817 not in {0.0})
#        If (feature 4417 in {1.0})
#         Predict: 3.337528612200947E8
#        Else (feature 4417 not in {1.0})
#         Predict: 7.497528612200948E8
#      Else (feature 3976 not in {0.0})
#       Predict: 1.2971540912734103E9
#     Else (feature 2955 not in {0.0})
#      Predict: 1.2972292774002185E9
#   Tree 31 (weight 0.1):
#     If (feature 4417 in {0.0})
#      If (feature 108 in {0.0})
#       If (feature 374 in {0.0})
#        If (feature 4421 in {0.0})
#         If (feature 826 in {0.0})
#          If (feature 4431 in {0.0})
#           Predict: -8471514.964013614
#          Else (feature 4431 not in {0.0})
#           Predict: 1.1831365315162367E8
#         Else (feature 826 not in {0.0})
#          If (feature 0 <= 3.675)
#           Predict: 1.7694238005315652E8
#          Else (feature 0 > 3.675)
#           Predict: 1.0369423800531565E9
#        Else (feature 4421 not in {0.0})
#         If (feature 309 in {0.0})
#          If (feature 0 <= 2.715)
#           Predict: -739062.5412744441
#          Else (feature 0 > 2.715)
#           Predict: 5.0014644002467014E7
#         Else (feature 309 not in {0.0})
#          If (feature 0 <= 3.3049999999999997)
#           Predict: 1.4923288299912653E9
#          Else (feature 0 > 3.3049999999999997)
#           Predict: 1514188.3559372425
#       Else (feature 374 not in {0.0})
#        If (feature 0 <= 3.4450000000000003)
#         Predict: -2.6328380741311207E8
#        Else (feature 0 > 3.4450000000000003)
#         If (feature 4424 in {1.0})
#          Predict: -2.6482999563967204E8
#         Else (feature 4424 not in {1.0})
#          Predict: 1.452641526684803E9
#      Else (feature 108 not in {0.0})
#       If (feature 4415 in {0.0})
#        If (feature 4419 in {0.0})
#         If (feature 4416 in {0.0})
#          If (feature 0 <= 3.495)
#           Predict: -3.023637149652214E9
#          Else (feature 0 > 3.495)
#           Predict: 2.2600833905550003E7
#         Else (feature 4416 not in {0.0})
#          If (feature 0 <= 3.495)
#           Predict: 9.152662850347786E9
#          Else (feature 0 > 3.495)
#           Predict: 9187850.34778595
#        Else (feature 4419 not in {0.0})
#         Predict: 9.152662850347786E9
#       Else (feature 4415 not in {0.0})
#        Predict: 9.152662850347786E9
#     Else (feature 4417 not in {0.0})
#      If (feature 108 in {1.0})
#       Predict: -1.5199937149652214E10
#      Else (feature 108 not in {1.0})
#       If (feature 17 in {0.0})
#        If (feature 864 in {0.0})
#         If (feature 394 in {0.0})
#          If (feature 1234 in {0.0})
#           Predict: 3.850348967687147E7
#          Else (feature 1234 not in {0.0})
#           Predict: 1.0478320905971069E9
#         Else (feature 394 not in {0.0})
#          Predict: 1.0684631488923645E9
#        Else (feature 864 not in {0.0})
#         Predict: 1.136942380053154E9
#       Else (feature 17 not in {0.0})
#        If (feature 0 <= 3.885)
#         Predict: 2.8569489431714296E9
#        Else (feature 0 > 3.885)
#         Predict: 7.256707304231105E8
#   Tree 32 (weight 0.1):
#     If (feature 2935 in {0.0})
#      If (feature 185 in {0.0})
#       If (feature 114 in {0.0})
#        If (feature 0 <= 2.625)
#         If (feature 556 in {0.0})
#          If (feature 1250 in {0.0})
#           Predict: -2.3720906752264597E7
#          Else (feature 1250 not in {0.0})
#           Predict: 2.0009974596612625E9
#         Else (feature 556 not in {0.0})
#          Predict: 2.1338316061958542E9
#        Else (feature 0 > 2.625)
#         If (feature 2083 in {0.0})
#          If (feature 2058 in {0.0})
#           Predict: 3860152.7944750874
#          Else (feature 2058 not in {0.0})
#           Predict: 8.578974427550621E8
#         Else (feature 2083 not in {0.0})
#          Predict: 8.586811352322807E8
#       Else (feature 114 not in {0.0})
#        If (feature 0 <= 2.4450000000000003)
#         If (feature 4421 in {1.0})
#          Predict: 9.085496891097746E8
#         Else (feature 4421 not in {1.0})
#          If (feature 4417 in {1.0})
#           Predict: 9.10223277319562E8
#          Else (feature 4417 not in {1.0})
#           Predict: 9.196182782477388E8
# ...
#         If (feature 4421 in {1.0})
#          Predict: 5.205245033747716E8
#         Else (feature 4421 not in {1.0})
#          Predict: 6.654912068663757E8
#       Else (feature 3520 not in {0.0})
#        Predict: 1.0710457536884904E9
#      Else (feature 2920 not in {0.0})
#       Predict: 7.576049141359358E8
#     Else (feature 928 not in {0.0})
#      If (feature 0 <= 3.0149999999999997)
#       If (feature 4417 in {1.0})
#        Predict: 9.840673554730482E8
#       Else (feature 4417 not in {1.0})
#        Predict: 9.934623564012251E8
#      Else (feature 0 > 3.0149999999999997)
#       If (feature 4414 in {0.0})
#        Predict: 1.5378235640122518E8
#       Else (feature 4414 not in {0.0})
#        Predict: 1.5378235640122515E8
#   Tree 37 (weight 0.1):
#     If (feature 842 in {0.0})
#      If (feature 29 in {0.0})
#       If (feature 468 in {0.0})
#        If (feature 563 in {0.0})
#         If (feature 808 in {0.0})
#          If (feature 697 in {0.0})
#           Predict: -1246607.5084024142
#          Else (feature 697 not in {0.0})
#           Predict: 4.277305707992363E8
#         Else (feature 808 not in {0.0})
#          If (feature 0 <= 2.935)
#           Predict: 4.7210216457579225E7
#          Else (feature 0 > 2.935)
#           Predict: 1.0025127159934907E9
#        Else (feature 563 not in {0.0})
#         If (feature 4418 in {1.0})
#          Predict: 2.7121021645757926E8
#         Else (feature 4418 not in {1.0})
#          If (feature 4420 in {1.0})
#           Predict: 3.7321021645757926E8
#          Else (feature 4420 not in {1.0})
#           Predict: 5.2007854948152024E8
#       Else (feature 468 not in {0.0})
#        If (feature 0 <= 3.075)
#         If (feature 4417 in {1.0})
#          Predict: 1.8258861795074782E8
#         Else (feature 4417 not in {1.0})
#          Predict: 1.9198361887892482E8
#        Else (feature 0 > 3.075)
#         If (feature 0 <= 3.435)
#          If (feature 4417 in {1.0})
#           Predict: 5.921886179507477E8
#          Else (feature 4417 not in {1.0})
#           Predict: 6.015836188789248E8
#         Else (feature 0 > 3.435)
#          If (feature 4417 in {1.0})
#           Predict: 4.001886179507479E8
#          Else (feature 4417 not in {1.0})
#           Predict: 4.0958361887892497E8
#      Else (feature 29 not in {0.0})
#       If (feature 0 <= 3.795)
#        Predict: -6.128195744498761E7
#       Else (feature 0 > 3.795)
#        If (feature 4416 in {1.0})
#         If (feature 0 <= 3.865)
#          Predict: 1.387060425550124E8
#         Else (feature 0 > 3.865)
#          Predict: 7.803937588834573E7
#        Else (feature 4416 not in {1.0})
#         If (feature 0 <= 3.865)
#          If (feature 4417 in {1.0})
#           Predict: 1.2931104162683536E8
#          Else (feature 4417 not in {1.0})
#           Predict: 1.387060425550124E8
#         Else (feature 0 > 3.865)
#          If (feature 0 <= 3.995)
#           Predict: 3.199708963003213E8
#          Else (feature 0 > 3.995)
#           Predict: 2.1520642416455004E8
#     Else (feature 842 not in {0.0})
#      If (feature 0 <= 1.795)
#       Predict: 5.430998307882729E8
#      Else (feature 0 > 1.795)
#       If (feature 4417 in {1.0})
#        Predict: 4.2578861795074785E8
#       Else (feature 4417 not in {1.0})
#        Predict: 4.351836188789249E8
#   Tree 38 (weight 0.1):
#     If (feature 3909 in {0.0})
#      If (feature 835 in {0.0})
#       If (feature 2955 in {0.0})
#        If (feature 3976 in {0.0})
#         If (feature 2342 in {0.0})
#          If (feature 3071 in {0.0})
#           Predict: -552682.353203383
#          Else (feature 3071 not in {0.0})
#           Predict: 7.337254007664828E8
#         Else (feature 2342 not in {0.0})
#          If (feature 4414 in {0.0})
#           Predict: 7.290279003023945E8
#          Else (feature 4414 not in {0.0})
#           Predict: 7.384229012305716E8
#        Else (feature 3976 not in {0.0})
#         Predict: 1.039736257022264E9
#       Else (feature 2955 not in {0.0})
#        Predict: 1.0397964059237103E9
#      Else (feature 835 not in {0.0})
#       Predict: 5.206336734511116E8
#     Else (feature 3909 not in {0.0})
#      Predict: 1.0423840558152504E9
#   Tree 39 (weight 0.1):
#     If (feature 1835 in {0.0})
#      If (feature 550 in {0.0})
#       If (feature 817 in {0.0})
#        If (feature 88 in {0.0})
#         If (feature 593 in {0.0})
#          If (feature 2765 in {0.0})
#           Predict: -946459.3377533733
#          Else (feature 2765 not in {0.0})
#           Predict: 1.0176034926638889E9
#         Else (feature 593 not in {0.0})
#          If (feature 0 <= 2.7649999999999997)
#           Predict: 6.124318202026739E8
#          Else (feature 0 > 2.7649999999999997)
#           Predict: 2.315634871787331E8
#        Else (feature 88 not in {0.0})
#         If (feature 0 <= 3.875)
#          If (feature 0 <= 3.795)
#           Predict: 2.5269916816301298E8
#          Else (feature 0 > 3.795)
#           Predict: 4.3906590052733356E8
#         Else (feature 0 > 3.875)
#          If (feature 4423 in {0.0})
#           Predict: 1.9552779006903687E8
#          Else (feature 4423 not in {0.0})
#           Predict: 2.390659005273335E8
#       Else (feature 817 not in {0.0})
#        If (feature 4417 in {1.0})
#         Predict: 2.5973080852207577E8
#        Else (feature 4417 not in {1.0})
#         Predict: 6.019258094502529E8
#      Else (feature 550 not in {0.0})
#       If (feature 0 <= 3.025)
#        Predict: 9.390659005273335E8
#       Else (feature 0 > 3.025)
#        If (feature 0 <= 3.425)
#         If (feature 4421 in {1.0})
#          Predict: 1.1784657008062066E8
#         Else (feature 4421 not in {1.0})
#          If (feature 4414 in {0.0})
#           Predict: 1.2967089959915651E8
#          Else (feature 4414 not in {0.0})
#           Predict: 1.3906590052733356E8
#        Else (feature 0 > 3.425)
#         Predict: 2.3906590052733356E8
#     Else (feature 1835 not in {0.0})
#      If (feature 4417 in {1.0})
#       Predict: 5.925647736574426E8
#      Else (feature 4417 not in {1.0})
#       If (feature 4416 in {0.0})
#        Predict: 6.019597745856196E8
#       Else (feature 4416 not in {0.0})
#        Predict: 6.019597745856198E8
#   Tree 40 (weight 0.1):
#     If (feature 556 in {0.0})
#      If (feature 0 <= 2.3049999999999997)
#       If (feature 1250 in {0.0})
#        If (feature 509 in {0.0})
#         If (feature 3767 in {0.0})
#          If (feature 1234 in {0.0})
#           Predict: -3.1425077798573937E7
#          Else (feature 1234 not in {0.0})
#           Predict: 8.444003937359619E8
#         Else (feature 3767 not in {0.0})
#          Predict: 8.743198457862625E8
#        Else (feature 509 not in {0.0})
#         If (feature 0 <= 2.025)
#          If (feature 4417 in {1.0})
#           Predict: 5.88511359794879E8
#          Else (feature 4417 not in {1.0})
#           Predict: 5.960273605374203E8
#         Else (feature 0 > 2.025)
#          Predict: 2.9769535979487896E8
#       Else (feature 1250 not in {0.0})
#        Predict: 1.6021885076368256E9
#      Else (feature 0 > 2.3049999999999997)
#       If (feature 1909 in {0.0})
#        If (feature 4414 in {1.0})
#         If (feature 108 in {1.0})
#          If (feature 0 <= 3.4850000000000003)
#           Predict: -2.4182912103728466E9
#          Else (feature 0 > 3.4850000000000003)
#           Predict: 5286192.915600777
#         Else (feature 108 not in {1.0})
#          If (feature 667 in {0.0})
#           Predict: -1.3860877846784784E7
#          Else (feature 667 not in {0.0})
#           Predict: 1.0714105132845535E9
#        Else (feature 4414 not in {1.0})
#         If (feature 108 in {0.0})
#          If (feature 309 in {0.0})
#           Predict: 6754062.741421638
#          Else (feature 309 not in {0.0})
#           Predict: 4.961970532540436E8
#         Else (feature 108 not in {0.0})
#          If (feature 4417 in {1.0})
#           Predict: -1.2159331210372847E10
#          Else (feature 4417 not in {1.0})
#           Predict: 1.568111290945369E9
#       Else (feature 1909 not in {0.0})
#        Predict: 8.392551923948841E8
#     Else (feature 556 not in {0.0})
#      If (feature 0 <= 2.3049999999999997)
#       Predict: 1.7084558248645039E9
#      Else (feature 0 > 2.3049999999999997)
#       If (feature 0 <= 2.835)
#        If (feature 4414 in {0.0})
#         Predict: 2.3485011554477984E8
#        Else (feature 4414 not in {0.0})
#         Predict: 2.348501155447799E8
#       Else (feature 0 > 2.835)
#        Predict: -1.7314988445522022E8
#   Tree 41 (weight 0.1):
#     If (feature 2935 in {0.0})
#      If (feature 374 in {0.0})
#       If (feature 185 in {0.0})
#        If (feature 114 in {0.0})
#         If (feature 1401 in {0.0})
#          If (feature 864 in {0.0})
#           Predict: -1001701.9692047442
#          Else (feature 864 not in {0.0})
#           Predict: 4.92900179154562E8
#         Else (feature 1401 not in {0.0})
#          If (feature 4421 in {1.0})
#           Predict: 5.56685049399887E8
#          Else (feature 4421 not in {1.0})
#           Predict: 5.779043798465998E8
#        Else (feature 114 not in {0.0})
#         If (feature 0 <= 2.465)
#          If (feature 4421 in {1.0})
#           Predict: 7.268794786473551E8
#          Else (feature 4421 not in {1.0})
#           Predict: 7.332290163768793E8
#         Else (feature 0 > 2.465)
#          If (feature 0 <= 2.885)
#           Predict: -4.175352579776021E7
#          Else (feature 0 > 2.885)
#           Predict: 1.2862625604638521E8
#       Else (feature 185 not in {0.0})
#        If (feature 0 <= 3.495)
#         If (feature 0 <= 3.2649999999999997)
#          If (feature 0 <= 2.885)
#           Predict: -3556259.78454415
#          Else (feature 0 > 2.885)
#           Predict: 1.7915140292133626E8
#         Else (feature 0 > 3.2649999999999997)
#          If (feature 4414 in {0.0})
#           Predict: 3.9894907379630303E8
#          Else (feature 4414 not in {0.0})
#           Predict: 4.0307206191394436E8
#        Else (feature 0 > 3.495)
#         If (feature 4414 in {0.0})
#          Predict: 9.034330730537615E8
#         Else (feature 4414 not in {0.0})
#          Predict: 9.150720619139445E8
#      Else (feature 374 not in {0.0})
#       If (feature 0 <= 3.4450000000000003)
#        If (feature 4414 in {0.0})
#         Predict: -2.11359349129849E8
#        Else (feature 4414 not in {0.0})
#         Predict: -2.072363610122078E8
#       Else (feature 0 > 3.4450000000000003)
#        If (feature 4424 in {1.0})
#         Predict: -2.12596299711097E8
#        Else (feature 4424 not in {1.0})
#         If (feature 4414 in {0.0})
#          Predict: 1.161380918148487E9
#         Else (feature 4414 not in {0.0})
#          Predict: 1.1655039062661285E9
#     Else (feature 2935 not in {0.0})
#      If (feature 4414 in {0.0})
#       Predict: 7.014691222030773E8
#      Else (feature 4414 not in {0.0})
#       Predict: 7.131081110632601E8
#   Tree 42 (weight 0.1):
#     If (feature 81 in {0.0})
#      If (feature 2083 in {0.0})
#       If (feature 826 in {0.0})
#        If (feature 1374 in {0.0})
#         If (feature 4417 in {0.0})
#          If (feature 108 in {0.0})
#           Predict: -4000050.6981620723
#          Else (feature 108 not in {0.0})
#           Predict: 6.627717625530187E8
#         Else (feature 4417 not in {0.0})
#          If (feature 108 in {1.0})
#           Predict: -9.727264627904436E9
#          Else (feature 108 not in {1.0})
#           Predict: 3.1362307158249486E7
#        Else (feature 1374 not in {0.0})
#         If (feature 4415 in {0.0})
#          If (feature 4418 in {0.0})
#           Predict: 4.853447548685807E8
#          Else (feature 4418 not in {0.0})
#           Predict: 4.853447548685806E8
#         Else (feature 4415 not in {0.0})
#          Predict: 4.853447548685808E8
#       Else (feature 826 not in {0.0})
#        If (feature 0 <= 3.685)
#         If (feature 4414 in {0.0})
#          Predict: 1.410219412370068E8
#         Else (feature 4414 not in {0.0})
#          Predict: 1.4514492935464808E8
#        Else (feature 0 > 3.685)
#         If (feature 4414 in {0.0})
#          Predict: 8.290219412370069E8
#         Else (feature 4414 not in {0.0})
#          Predict: 8.331449293546481E8
#      Else (feature 2083 not in {0.0})
#       If (feature 4414 in {0.0})
#        Predict: 6.871849759392014E8
#       Else (feature 4414 not in {0.0})
#        Predict: 6.913079640568428E8
#     Else (feature 81 not in {0.0})
#      If (feature 0 <= 3.225)
#       If (feature 4421 in {1.0})
#        Predict: 2.96885389793728E8
#       Else (feature 4421 not in {1.0})
#        If (feature 4417 in {1.0})
#         Predict: 3.0870971931226385E8
#        Else (feature 4417 not in {1.0})
#         Predict: 3.181047202404409E8
#      Else (feature 0 > 3.225)
#       If (feature 4422 in {1.0})
#        Predict: 7.810472024044085E7
#       Else (feature 4422 not in {1.0})
#        If (feature 4415 in {1.0})
#         Predict: 1.2210472024044085E8
#        Else (feature 4415 not in {1.0})
#         If (feature 4431 in {1.0})
#          Predict: 1.3253637450055543E8
#         Else (feature 4431 not in {1.0})
#          If (feature 4417 in {0.0})
#           Predict: 1.92938921106427E8
#          Else (feature 4417 not in {0.0})
#           Predict: 2.2004305264559713E8
#   Tree 43 (weight 0.1):
#     If (feature 2058 in {0.0})
#      If (feature 1496 in {0.0})
#       If (feature 803 in {0.0})
#        If (feature 997 in {0.0})
#         If (feature 394 in {0.0})
#          If (feature 877 in {0.0})
#           Predict: -837313.3624537013
#          Else (feature 877 not in {0.0})
#           Predict: 4.2377899034987795E8
#         Else (feature 394 not in {0.0})
#          If (feature 0 <= 3.475)
#           Predict: -8.789367819541459E7
#          Else (feature 0 > 3.475)
#           Predict: 5.2060615960065407E8
#        Else (feature 997 not in {0.0})
#         If (feature 4417 in {1.0})
#          Predict: 4.159433231669107E8
#         Else (feature 4417 not in {1.0})
#          If (feature 4414 in {0.0})
#           Predict: 4.3053179548073465E8
#          Else (feature 4414 not in {0.0})
#           Predict: 4.3465478359837604E8
#       Else (feature 803 not in {0.0})
#        If (feature 0 <= 3.965)
#         If (feature 4414 in {0.0})
#          Predict: 1.433033873516492E9
#         Else (feature 4414 not in {0.0})
#          Predict: 1.4371568616341333E9
#        Else (feature 0 > 3.965)
#         If (feature 4414 in {0.0})
#          Predict: -2.434462124995072E8
#         Else (feature 4414 not in {0.0})
#          Predict: -2.3932322438186598E8
#      Else (feature 1496 not in {0.0})
#       If (feature 4417 in {1.0})
#        Predict: 5.49043261921025E8
#       Else (feature 4417 not in {1.0})
#        Predict: 5.636317342348487E8
#     Else (feature 2058 not in {0.0})
#      Predict: 6.873580320970587E8
#   Tree 44 (weight 0.1):
#     If (feature 1678 in {0.0})
#      If (feature 4253 in {0.0})
#       If (feature 223 in {0.0})
#        If (feature 594 in {0.0})
#         If (feature 902 in {0.0})
#          If (feature 1526 in {0.0})
#           Predict: -795342.7377318623
#          Else (feature 1526 not in {0.0})
#           Predict: 5.3495736492529106E8
#         Else (feature 902 not in {0.0})
#          If (feature 0 <= 3.255)
#           Predict: 4.766581353350661E8
#          Else (feature 0 > 3.255)
#           Predict: 3.2062672328276217E8
#        Else (feature 594 not in {0.0})
#         If (feature 0 <= 3.255)
#          If (feature 4417 in {1.0})
#           Predict: 4.905466388108926E8
#          Else (feature 4417 not in {1.0})
#           Predict: 5.051351111247158E8
#         Else (feature 0 > 3.255)
#          If (feature 4417 in {1.0})
#           Predict: 1.4158054601089323E8
#          Else (feature 4417 not in {1.0})
#           Predict: 1.5823051238353777E8
#       Else (feature 223 not in {0.0})
#        If (feature 4432 in {0.0})
#         If (feature 0 <= 3.075)
#          If (feature 4417 in {1.0})
#           Predict: 5.124405917438059E8
#          Else (feature 4417 not in {1.0})
#           Predict: 5.270290640576298E8
#         Else (feature 0 > 3.075)
#          If (feature 0 <= 3.385)
#           Predict: 1.6009573072429648E8
#          Else (feature 0 > 3.385)
#           Predict: 2.9479359675250813E7
#        Else (feature 4432 not in {0.0})
#         Predict: 9.750290640576298E8
#      Else (feature 4253 not in {0.0})
#       Predict: 9.431951811702051E8
#     Else (feature 1678 not in {0.0})
#      If (feature 4417 in {1.0})
#       Predict: 5.3427867624882996E8
#      Else (feature 4417 not in {1.0})
#       Predict: 5.507461487482893E8

# %%
import pandas as pd
def ExtractFeatureImp(featureImp, dataset, featuresCol):
    list_extract = []
    for i in dataset.schema[featuresCol].metadata["ml_attr"]["attrs"]:
        list_extract = list_extract + dataset.schema[featuresCol].metadata["ml_attr"]["attrs"][i]
    varlist = pd.DataFrame(list_extract)
    varlist['score'] = varlist['idx'].apply(lambda x: featureImp[x])
    return(varlist.sort_values('score', ascending = False))

ExtractFeatureImp(gbt_model.featureImportances, train_df, "features").head(50)
#print(rf_model.featureImportances)
# Out:
#        idx                                               name     score
# 0        0                         continuous_features_rating  0.249237
# 374    374            director_indexed_encoded_Chan-wook Park  0.050678
# 4424  4424                     genres_indexed_encoded_Mystery  0.033493
# 108    108              director_indexed_encoded_Bong Joon Ho  0.032679
# 4417  4417                      genres_indexed_encoded_Action  0.022335
# 2083  2083             director_indexed_encoded_Ajay Pannalal  0.021404
# 3976  3976                  director_indexed_encoded_Jung Huh  0.020639
# 2955  2955              director_indexed_encoded_Lajos Koltai  0.020469
# 17      17            director_indexed_encoded_Hayao Miyazaki  0.020276
# 835    835              director_indexed_encoded_Rohit Shetty  0.019701
# 594    594   director_indexed_encoded_S. Shankar (as Shankar)  0.017595
# 394    394              director_indexed_encoded_Mamoru Oshii  0.017197
# 3909  3909            director_indexed_encoded_Chang-dong Lee  0.016888
# 1210  1210           director_indexed_encoded_Katsuhiro Ôtomo  0.016179
# 2920  2920               director_indexed_encoded_János Szász  0.015777
# 697    697     director_indexed_encoded_Sanjay Leela Bhansali  0.015548
# 803    803             director_indexed_encoded_Isao Takahata  0.015286
# 2765  2765              director_indexed_encoded_Biyi Bandele  0.014739
# 593    593                  director_indexed_encoded_Siddique  0.013505
# 1224  1224              director_indexed_encoded_Yong-hwa Kim  0.013405
# 3071  3071               director_indexed_encoded_Sohail Khan  0.013150
# 2342  2342            director_indexed_encoded_Boyapati Srinu  0.013146
# 114    114             director_indexed_encoded_Rakesh Roshan  0.012675
# 1496  1496               director_indexed_encoded_Abhinay Deo  0.012579
# 2935  2935        director_indexed_encoded_Trivikram Srinivas  0.011513
# 309    309            director_indexed_encoded_S.S. Rajamouli  0.011285
# 902    902           director_indexed_encoded_Surrender Reddy  0.010481
# 817    817  director_indexed_encoded_Gautham Vasudev Menon...  0.010327
# 1678  1678           director_indexed_encoded_Vikram K. Kumar  0.010163
# 1835  1835           director_indexed_encoded_Rajesh M. Selva  0.009989
# 556    556        director_indexed_encoded_Sooraj R. Barjatya  0.009851
# 842    842             director_indexed_encoded_Sreenu Vaitla  0.009832
# 468    468                director_indexed_encoded_K.V. Anand  0.009742
# 1250  1250                director_indexed_encoded_Kabir Khan  0.009727
# 509    509               director_indexed_encoded_Prabhu Deva  0.009248
# 223    223           director_indexed_encoded_A.R. Murugadoss  0.008934
# 928    928               director_indexed_encoded_Atlee Kumar  0.008549
# 1406  1406               director_indexed_encoded_Zoya Akhtar  0.008310
# 659    659             director_indexed_encoded_Venkat Prabhu  0.007597
# 997    997               director_indexed_encoded_Arbaaz Khan  0.006995
# 2058  2058          director_indexed_encoded_Luchino Visconti  0.006836
# 3520  3520          director_indexed_encoded_Kornél Mundruczó  0.006727
# 563    563             director_indexed_encoded_Sanjay Gadhvi  0.006539
# 808    808             director_indexed_encoded_Vishnuvardhan  0.006518
# 1234  1234             director_indexed_encoded_Anand Shankar  0.006469
# 4425  4425                    genres_indexed_encoded_Children  0.006298
# 4415  4415                      genres_indexed_encoded_Comedy  0.006281
# 831    831               director_indexed_encoded_Anurag Basu  0.006232
# 4423  4423                     genres_indexed_encoded_Fantasy  0.006031
# 4431  4431                        genres_indexed_encoded_IMAX  0.005894

# %%
### PMML EXAMPLE
#formula            = RFormula(formula = "budgetvalue ~ .")
#gbt                = GBTRegressor(featuresCol='features', labelCol='budgetvalue',seed=9)
#join_pipeline_gbt  = [formula, gbt]
#gbt_pipeline       = Pipeline(stages = join_pipeline_gbt)
#gbt_final          = gbt_pipeline.fit(train_df_2) 
#
#
#### EXPORTING THE MODEL
#PMMLBuilder(sc, data_df, gbt_final) \
#    .putOption(gbt, "compact", True) \
#    .putOption(gbt, "keep_predictionCol", True) \
#    .buildFile("gbt_budget.pmml")
