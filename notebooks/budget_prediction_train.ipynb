# %%
#import sys
#sys.path.append('jars/mleap/python')
#import mleap.pyspark
#from mleap.pyspark.spark_support import SimpleSparkSerializer
from pyspark import SparkContext
from pyspark.sql import SparkSession,SQLContext
from pyspark.sql.functions import *
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, OneHotEncoder, StandardScaler, RFormula, VectorIndexer
from pyspark.ml.regression import GBTRegressor, GBTRegressionModel
from pyspark.ml.regression import RandomForestRegressor, DecisionTreeRegressor
from pyspark.ml import Pipeline, PipelineModel
from pyspark.sql.types import *
from pyspark.ml.linalg import Vectors

# %%
SparkContext.setSystemProperty('spark.driver.memory', '2g')
SparkContext.setSystemProperty('spark.driver.cores', '3')
SparkContext.setSystemProperty('spark.executor.memory', '2g')
SparkContext.setSystemProperty('spark.executor.cores', '3')
SparkContext.setSystemProperty('spark.driver.memoryOverhead', '1g')
SparkContext.setSystemProperty('spark.storage.memoryFraction', '0.9')

# %%
data_df = spark.read.csv('../abt/data/*',header=True, inferSchema=True)
data_df.printSchema()
# Out:
# root
#  |-- idmovie: integer (nullable = true)
#  |-- runtime: integer (nullable = true)
#  |-- director: string (nullable = true)
#  |-- genres: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- budgetvalue: long (nullable = true)

# %% [markdown]
# ## Summary Statistics

# %% [markdown]
# #### Evaluating continuous features

# %%
data_df.summary().select('summary','budgetvalue', 'runtime','rating').show()
# Out:
# +-------+--------------------+------------------+------------------+
# |summary|         budgetvalue|           runtime|            rating|
# +-------+--------------------+------------------+------------------+
# |  count|               18495|             18495|             18495|
# |   mean|6.0121800647904836E7|100.06520681265206|3.1008229251148713|
# | stddev| 7.384994399567893E8|34.253022733437874|0.6089458576840447|
# |    min|                   1|                 0|               0.5|
# |    25%|             3000000|                91|              2.77|
# |    50%|            11500000|               101|              3.17|
# |    75%|            34000000|               116|              3.52|
# |    max|         35000000000|               359|               5.0|
# +-------+--------------------+------------------+------------------+

# %% [markdown]
# #### Evaluating categorical features

# %%
data_df.registerTempTable('movie')

# %%
### EVALUATING DIRECTORS
dfsql = sqlContext.sql("""select director, count(*) as total, sum(budgetvalue) as budgetval 
                            from (select distinct director, 
                                                  budgetvalue 
                                  from movie) as tmp
                            group by director
                            order by total desc
                      """)
dfsql.show()
# Out:
# +-----------------+-----+----------+
# |         director|total| budgetval|
# +-----------------+-----+----------+
# | Steven Spielberg|   27|1738950000|
# |      Woody Allen|   23| 369950000|
# |  Martin Scorsese|   20| 783900000|
# |       Ron Howard|   19|1153602000|
# |     Ridley Scott|   19|1277900000|
# |Steven Soderbergh|   19| 489900000|
# |   Clint Eastwood|   19| 637300000|
# |   John Carpenter|   16| 217235000|
# | Alfred Hitchcock|   15|  32405322|
# |   Brian De Palma|   15| 333300000|
# |       Rob Reiner|   14| 476000000|
# |       Wes Craven|   14| 200530000|
# |  Joel Schumacher|   13| 533000000|
# |  Robert Zemeckis|   13| 988000000|
# |        Spike Lee|   13| 214320000|
# |   Barry Levinson|   13| 384000000|
# |        John Ford|   13|  25226000|
# |   Stephen Frears|   13| 285750000|
# |     Renny Harlin|   12| 542000000|
# |      Walter Hill|   12| 296200000|
# +-----------------+-----+----------+
# only showing top 20 rows

# %%
### EVALUATING GENRES
dfsql = sqlContext.sql("""select genres, count(*) as total, sum(budgetvalue) as budgetval 
                            from movie
                            group by genres
                            order by total desc
                      """)
dfsql.show()
# Out:
# +------------------+-----+------------+
# |            genres|total|   budgetval|
# +------------------+-----+------------+
# |             Drama| 4002|208000414565|
# |            Comedy| 2477|106865019824|
# |          Thriller| 2182|119472614301|
# |            Action| 1739|186063609838|
# |           Romance| 1325| 65783279946|
# |            Horror| 1143| 24919813634|
# |             Crime| 1060| 35068607740|
# |         Adventure|  915| 98451049103|
# |            Sci-Fi|  784| 52212339263|
# |           Fantasy|  543| 71902986518|
# |           Mystery|  536| 17964721321|
# |          Children|  383| 18381639741|
# |               War|  315| 48729442096|
# |       Documentary|  230|   539092614|
# |           Musical|  220|  8494231643|
# |         Animation|  203| 26464556091|
# |           Western|  158|  2892246885|
# |              IMAX|  120| 15454100000|
# |(no genres listed)|  116|  4026313753|
# |         Film-Noir|   44|   266624107|
# +------------------+-----+------------+

# %%
dfsql = sqlContext.sql("""select * from movie where director is not null""")
dfsql.count()
dfsql.show()
# Out:
# +-------+-------+--------------------+---------+------+-----------+
# |idmovie|runtime|            director|   genres|rating|budgetvalue|
# +-------+-------+--------------------+---------+------+-----------+
# |     26|    123|       Oliver Parker|    Drama|  3.61|   11000000|
# |    474|    128|   Wolfgang Petersen|   Action|  3.72|   40000000|
# |    474|    128|   Wolfgang Petersen| Thriller|  3.72|   40000000|
# |   1677|    107|        Sidney Lumet|   Comedy|  2.61|   12000000|
# |   1677|    107|        Sidney Lumet|    Drama|  2.61|   12000000|
# |   1806|     91|        John Roberts|Adventure|  2.83|   23000000|
# |   1806|     91|        John Roberts| Children|  2.83|   23000000|
# |   1806|     91|        John Roberts|   Comedy|  2.83|   23000000|
# |   2529|    112|Franklin J. Schaf...|   Action|   3.6|    5800000|
# |   2529|    112|Franklin J. Schaf...|    Drama|   3.6|    5800000|
# |   2529|    112|Franklin J. Schaf...|   Sci-Fi|   3.6|    5800000|
# |   2927|     86|          David Lean|    Drama|  3.96|     170000|
# |   2927|     86|          David Lean|  Romance|  3.96|     170000|
# |   3091|    180|      Akira Kurosawa|    Drama|  4.04|    6000000|
# |   3091|    180|      Akira Kurosawa|      War|  4.04|    6000000|
# |   4590|    119|       Paul Mazursky|    Drama|  3.56|    9500000|
# |   4823|     90|       Peter Chelsom|   Comedy|  3.35|   28000000|
# |   4823|     90|       Peter Chelsom|  Romance|  3.35|   28000000|
# |   5409|     95|    Dwight H. Little|   Action|  2.84|   10000000|
# |  32954|    122|       Fred Schepisi|    Drama|  3.48|    1280000|
# +-------+-------+--------------------+---------+------+-----------+
# only showing top 20 rows

# %% [markdown]
# #### Defining Features

# %%
#'runtime', 'rating','budgetvalue'
continuous_cols  = ['rating', 'budgetvalue']
categorical_cols = ['director','genres']

# %%
def featuresCreation(df):

    categorical_indexers = [
        StringIndexer(inputCol=column, outputCol="{0}_indexed".format(column), handleInvalid='keep')
        for column in categorical_cols
    ]

    categorical_features = [
        OneHotEncoder(
            inputCol=indexer.getOutputCol(),
            outputCol="{0}_encoded".format(indexer.getOutputCol()))
        for indexer in categorical_indexers
    ]

    continuous_feature = [VectorAssembler(
        inputCols=[column for column in continuous_cols],
        outputCol="continuous_features"
    )]

    #continuous_feature_standard = [StandardScaler(inputCol='continuous_features', outputCol='scaled_continuous_features')]

    #all_features = continuous_feature_standard + categorical_features
    all_features = continuous_feature + categorical_features

    universal_assembler = VectorAssembler(
        inputCols=[feature.getOutputCol() for feature in all_features],
        outputCol="features"
    )

    #estimator = categorical_indexers + \
    #            categorical_features + \
    #            continuous_feature + \
    #            continuous_feature_standard + \
    #            [universal_assembler]

    estimator = categorical_indexers + \
                categorical_features + \
                continuous_feature + \
                [universal_assembler]
    
    universal_pipeline = Pipeline(stages=estimator)
    #universal_pipeline.save('budget_prediction_pipeline/')
    data_features_df   = universal_pipeline.fit(df).transform(df)
    
    return data_features_df

# %%
data_features_df = featuresCreation(data_df)

# %%
data_features_df.show()
# Out:
# +-------+-------+--------------------+---------+------+-----------+----------------+--------------+------------------------+----------------------+-------------------+--------------------+
# |idmovie|runtime|            director|   genres|rating|budgetvalue|director_indexed|genres_indexed|director_indexed_encoded|genres_indexed_encoded|continuous_features|            features|
# +-------+-------+--------------------+---------+------+-----------+----------------+--------------+------------------------+----------------------+-------------------+--------------------+
# |     26|    123|       Oliver Parker|    Drama|  3.61|   11000000|           407.0|           0.0|      (4413,[407],[1.0])|        (20,[0],[1.0])|       [3.61,1.1E7]|(4435,[0,1,409,44...|
# |    474|    128|   Wolfgang Petersen|   Action|  3.72|   40000000|            47.0|           3.0|       (4413,[47],[1.0])|        (20,[3],[1.0])|       [3.72,4.0E7]|(4435,[0,1,49,441...|
# |    474|    128|   Wolfgang Petersen| Thriller|  3.72|   40000000|            47.0|           2.0|       (4413,[47],[1.0])|        (20,[2],[1.0])|       [3.72,4.0E7]|(4435,[0,1,49,441...|
# |   1677|    107|        Sidney Lumet|   Comedy|  2.61|   12000000|            31.0|           1.0|       (4413,[31],[1.0])|        (20,[1],[1.0])|       [2.61,1.2E7]|(4435,[0,1,33,441...|
# |   1677|    107|        Sidney Lumet|    Drama|  2.61|   12000000|            31.0|           0.0|       (4413,[31],[1.0])|        (20,[0],[1.0])|       [2.61,1.2E7]|(4435,[0,1,33,441...|
# |   1806|     91|        John Roberts|Adventure|  2.83|   23000000|          1705.0|           7.0|     (4413,[1705],[1.0])|        (20,[7],[1.0])|       [2.83,2.3E7]|(4435,[0,1,1707,4...|
# |   1806|     91|        John Roberts| Children|  2.83|   23000000|          1705.0|          11.0|     (4413,[1705],[1.0])|       (20,[11],[1.0])|       [2.83,2.3E7]|(4435,[0,1,1707,4...|
# |   1806|     91|        John Roberts|   Comedy|  2.83|   23000000|          1705.0|           1.0|     (4413,[1705],[1.0])|        (20,[1],[1.0])|       [2.83,2.3E7]|(4435,[0,1,1707,4...|
# |   2529|    112|Franklin J. Schaf...|   Action|   3.6|    5800000|           461.0|           3.0|      (4413,[461],[1.0])|        (20,[3],[1.0])|    [3.6,5800000.0]|(4435,[0,1,463,44...|
# |   2529|    112|Franklin J. Schaf...|    Drama|   3.6|    5800000|           461.0|           0.0|      (4413,[461],[1.0])|        (20,[0],[1.0])|    [3.6,5800000.0]|(4435,[0,1,463,44...|
# |   2529|    112|Franklin J. Schaf...|   Sci-Fi|   3.6|    5800000|           461.0|           8.0|      (4413,[461],[1.0])|        (20,[8],[1.0])|    [3.6,5800000.0]|(4435,[0,1,463,44...|
# |   2927|     86|          David Lean|    Drama|  3.96|     170000|           141.0|           0.0|      (4413,[141],[1.0])|        (20,[0],[1.0])|    [3.96,170000.0]|(4435,[0,1,143,44...|
# |   2927|     86|          David Lean|  Romance|  3.96|     170000|           141.0|           4.0|      (4413,[141],[1.0])|        (20,[4],[1.0])|    [3.96,170000.0]|(4435,[0,1,143,44...|
# |   3091|    180|      Akira Kurosawa|    Drama|  4.04|    6000000|          1333.0|           0.0|     (4413,[1333],[1.0])|        (20,[0],[1.0])|   [4.04,6000000.0]|(4435,[0,1,1335,4...|
# |   3091|    180|      Akira Kurosawa|      War|  4.04|    6000000|          1333.0|          12.0|     (4413,[1333],[1.0])|       (20,[12],[1.0])|   [4.04,6000000.0]|(4435,[0,1,1335,4...|
# |   4590|    119|       Paul Mazursky|    Drama|  3.56|    9500000|           430.0|           0.0|      (4413,[430],[1.0])|        (20,[0],[1.0])|   [3.56,9500000.0]|(4435,[0,1,432,44...|
# |   4823|     90|       Peter Chelsom|   Comedy|  3.35|   28000000|           340.0|           1.0|      (4413,[340],[1.0])|        (20,[1],[1.0])|       [3.35,2.8E7]|(4435,[0,1,342,44...|
# |   4823|     90|       Peter Chelsom|  Romance|  3.35|   28000000|           340.0|           4.0|      (4413,[340],[1.0])|        (20,[4],[1.0])|       [3.35,2.8E7]|(4435,[0,1,342,44...|
# |   5409|     95|    Dwight H. Little|   Action|  2.84|   10000000|          1292.0|           3.0|     (4413,[1292],[1.0])|        (20,[3],[1.0])|       [2.84,1.0E7]|(4435,[0,1,1294,4...|
# |  32954|    122|       Fred Schepisi|    Drama|  3.48|    1280000|           530.0|           0.0|      (4413,[530],[1.0])|        (20,[0],[1.0])|   [3.48,1280000.0]|(4435,[0,1,532,44...|
# +-------+-------+--------------------+---------+------+-----------+----------------+--------------+------------------------+----------------------+-------------------+--------------------+
# only showing top 20 rows

# %%
(train_df, test_df) = data_features_df.randomSplit([0.80,0.20])

# %%
### GRADIENT BOOSTING ##############################################################################################
gbt                = GBTRegressor(featuresCol='features',labelCol='budgetvalue', maxDepth=4, maxIter=40)
gbt_model          = gbt.fit(train_df)
print("### MODEL TRAINED")
gbt_pred           = gbt_model.transform(test_df)
print("### MODEL PREDICTED")
gbt_evaluator_rmse = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='rmse')
gbt_rmse           = gbt_evaluator_rmse.evaluate(gbt_pred)
gbt_evaluator_r2   = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='r2')
gbt_r2             = gbt_evaluator_r2.evaluate(gbt_pred)

print('### GRADIENT BOOSTED RMSE:')
print(gbt_rmse)
print('### GRADIENT BOOSTED r2:')
print(gbt_r2)
# Out:
# ### MODEL TRAINED
# ### MODEL PREDICTED
# ### GRADIENT BOOSTED RMSE:
# 287649740.6247738
# ### GRADIENT BOOSTED r2:
# 0.9203895171923617

# %%
### SAVING THE MODEL
gbt_model.save('../gbt_model/')

# %%
### MLEAP SERIALIZATION
#gbt_model.serializeToBundle("jar:file:jars/movies_gbt.zip", gbt_model.transform(data_features_df))

# %%
### RANDOM FOREST ##################################################################################################
rf = RandomForestRegressor(featuresCol='features', labelCol='budgetvalue', numTrees=15)

rf_model        = rf.fit(train_df)
rf_pred         = rf_model.transform(test_df)
rf_evaluator    = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='rmse')
rf_rmse         = rf_evaluator.evaluate(rf_pred)
rf_evaluator_r2 = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='r2')
rf_r2           = rf_evaluator_r2.evaluate(rf_pred)

print('### RANDOM FOREST RMSE:')
print(rf_rmse)
print('### RANDOM FOREST r2:')
print(rf_r2)
#rf_pred.withColumn('pred', rf_pred['prediction'].cast(DecimalType(30,2))).show(truncate=False)
# Out:
# ### RANDOM FOREST RMSE:
# 606585637.5503325
# ### RANDOM FOREST r2:
# 0.645981033089057

# %%
### DECISION TREE ###################################################################################################
dt              = DecisionTreeRegressor(featuresCol='features', labelCol='budgetvalue')
dt_model        = dt.fit(train_df)
dt_pred         = dt_model.transform(test_df)
dt_evaluator    = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='rmse')
dt_rmse         = dt_evaluator.evaluate(dt_pred)
dt_evaluator_r2 = RegressionEvaluator(labelCol='budgetvalue', predictionCol='prediction', metricName='r2')
dt_r2           = dt_evaluator_r2.evaluate(dt_pred)

print('### DECISION TREE RMSE:')
print(dt_rmse)
print('### RANDOM FOREST r2:')
print(dt_r2)
# Out:
# ### DECISION TREE RMSE:
# 262467966.77666622
# ### RANDOM FOREST r2:
# 0.9337181077789628

# %%
from pyspark.sql.types import DecimalType
print('DECISION TREE #########################')
dt_pred.selectExpr('idmovie','director','genres','rating','budgetvalue', 'cast(prediction as Decimal(38,0)) as prediction').show(10)
#################################################################################
print('RANDOM FOREST #########################')
rf_pred.selectExpr('idmovie','director','genres','rating','budgetvalue', 'cast(prediction as Decimal(38,0)) as prediction').show(10)
#################################################################################
print('GRADIENT BOOSTED #########################')
gbt_pred.selectExpr('idmovie','director','genres','rating','budgetvalue', 'cast(prediction as Decimal(38,0)) as prediction').show(10)
# Out:
# DECISION TREE #########################
# +-------+---------------+---------+------+-----------+----------+
# |idmovie|       director|   genres|rating|budgetvalue|prediction|
# +-------+---------------+---------+------+-----------+----------+
# |      1|  John Lasseter|Adventure|  3.89|   30000000|  32626287|
# |      1|  John Lasseter| Children|  3.89|   30000000|  32626287|
# |      3|  Howard Deutch|   Comedy|  3.17|   25000000|  32626287|
# |     10|Martin Campbell|   Action|  3.43|   60000000|  79045324|
# |     11|     Rob Reiner|  Romance|  3.66|   62000000|  79045324|
# |     15|   Renny Harlin|  Romance|  2.73|   98000000|  79045324|
# |     19| Steve Oedekerk|   Comedy|  2.64|   30000000|  32626287|
# |     23| Richard Donner|    Crime|  3.16|   50000000|  32626287|
# |     43|Michael Hoffman|    Drama|  3.47|   19000000|   5827821|
# |     50|   Bryan Singer| Thriller|  4.29|    6000000|   5827821|
# +-------+---------------+---------+------+-----------+----------+
# only showing top 10 rows
#
# RANDOM FOREST #########################
# +-------+---------------+---------+------+-----------+----------+
# |idmovie|       director|   genres|rating|budgetvalue|prediction|
# +-------+---------------+---------+------+-----------+----------+
# |      1|  John Lasseter|Adventure|  3.89|   30000000|  29533318|
# |      1|  John Lasseter| Children|  3.89|   30000000|  26991145|
# |      3|  Howard Deutch|   Comedy|  3.17|   25000000|  26991145|
# |     10|Martin Campbell|   Action|  3.43|   60000000|  51406306|
# |     11|     Rob Reiner|  Romance|  3.66|   62000000|  51416011|
# |     15|   Renny Harlin|  Romance|  2.73|   98000000|  53413616|
# |     19| Steve Oedekerk|   Comedy|  2.64|   30000000|  26991145|
# |     23| Richard Donner|    Crime|  3.16|   50000000|  26991145|
# |     43|Michael Hoffman|    Drama|  3.47|   19000000|  25215354|
# |     50|   Bryan Singer| Thriller|  4.29|    6000000|  23983105|
# +-------+---------------+---------+------+-----------+----------+
# only showing top 10 rows
#
# GRADIENT BOOSTED #########################
# +-------+---------------+---------+------+-----------+----------+
# |idmovie|       director|   genres|rating|budgetvalue|prediction|
# +-------+---------------+---------+------+-----------+----------+
# |      1|  John Lasseter|Adventure|  3.89|   30000000|  27139883|
# |      1|  John Lasseter| Children|  3.89|   30000000|  27139883|
# |      3|  Howard Deutch|   Comedy|  3.17|   25000000|  21523994|
# |     10|Martin Campbell|   Action|  3.43|   60000000|  78287492|
# |     11|     Rob Reiner|  Romance|  3.66|   62000000|  78287492|
# |     15|   Renny Harlin|  Romance|  2.73|   98000000|  94269463|
# |     19| Steve Oedekerk|   Comedy|  2.64|   30000000|  27139883|
# |     23| Richard Donner|    Crime|  3.16|   50000000|  37658681|
# |     43|Michael Hoffman|    Drama|  3.47|   19000000|  16667869|
# |     50|   Bryan Singer| Thriller|  4.29|    6000000|   4985152|
# +-------+---------------+---------+------+-----------+----------+
# only showing top 10 rows

# %%
print(gbt_model.toDebugString)
# Out:
# GBTRegressionModel (uid=GBTRegressor_7f39628e7341) with 40 trees
#   Tree 0 (weight 1.0):
#     If (feature 1225 in {0.0})
#      If (feature 3996 in {0.0})
#       If (feature 1 <= 1.825E8)
#        If (feature 1 <= 5.95E7)
#         Predict: 1.3283135428387718E7
#        Else (feature 1 > 5.95E7)
#         Predict: 9.814174126637554E7
#       Else (feature 1 > 1.825E8)
#        If (feature 684 in {0.0})
#         Predict: 7.30041992825986E8
#        Else (feature 684 not in {0.0})
#         Predict: 3.0E10
#      Else (feature 3996 not in {0.0})
#       Predict: 2.0E10
#     Else (feature 1225 not in {0.0})
#      Predict: 3.5E10
#   Tree 1 (weight 0.1):
#     If (feature 2837 in {0.0})
#      If (feature 109 in {0.0})
#       If (feature 2084 in {0.0})
#        If (feature 375 in {0.0})
#         Predict: -1.0240254120664967E7
#        Else (feature 375 not in {0.0})
#         Predict: 5.2881429534874525E9
#       Else (feature 2084 not in {0.0})
#        Predict: 8.539916014348027E9
#      Else (feature 109 not in {0.0})
#       If (feature 1 <= 5.68E7)
#        If (feature 0 <= 3.565)
#         Predict: 6.623372914322457E7
#        Else (feature 0 > 3.565)
#         Predict: -1.8451985142489724E7
#       Else (feature 1 > 5.68E7)
#        If (feature 4415 in {0.0})
#         Predict: 2.2970916014348026E10
#        Else (feature 4415 not in {0.0})
#         Predict: 2.297091601434803E10
#     Else (feature 2837 not in {0.0})
#      Predict: 1.8539916014348026E10
#   Tree 2 (weight 0.1):
#     If (feature 2837 in {0.0})
#      If (feature 109 in {0.0})
#       If (feature 2084 in {0.0})
#        If (feature 804 in {0.0})
#         Predict: -7917206.415995128
#        Else (feature 804 not in {0.0})
#         Predict: 5.1183311510902405E9
#       Else (feature 2084 not in {0.0})
#        Predict: 6.831932811478424E9
#      Else (feature 109 not in {0.0})
#       If (feature 1 <= 5.85E7)
#        If (feature 0 <= 3.575)
#         Predict: 5.298698331457964E7
#        Else (feature 0 > 3.575)
#         Predict: -1.4761588113991776E7
#       Else (feature 1 > 5.85E7)
#        Predict: 1.8376732811478424E10
#     Else (feature 2837 not in {0.0})
#      Predict: 1.4831932811478422E10
#   Tree 3 (weight 0.1):
#     If (feature 2837 in {0.0})
#      If (feature 375 in {0.0})
#       If (feature 109 in {0.0})
#        If (feature 18 in {0.0})
#         Predict: -9731651.787453573
#        Else (feature 18 not in {0.0})
#         Predict: 1.8953675448393052E9
#       Else (feature 109 not in {0.0})
#        If (feature 1 <= 5.55E7)
#         Predict: 1.320558665166372E7
#        Else (feature 1 > 5.55E7)
#         Predict: 1.470138624918274E10
#      Else (feature 375 not in {0.0})
#       If (feature 1 <= 1.29E7)
#        If (feature 1 <= 4100000.0)
#         Predict: -1.0752780869377337E9
#        Else (feature 1 > 4100000.0)
#         Predict: -1.0586114202710671E9
#       Else (feature 1 > 1.29E7)
#        Predict: 1.7483870864933735E10
#     Else (feature 2837 not in {0.0})
#      Predict: 1.1865546249182737E10
#   Tree 4 (weight 0.1):
#     If (feature 2837 in {0.0})
#      If (feature 2084 in {0.0})
#       If (feature 804 in {0.0})
#        If (feature 375 in {0.0})
#         Predict: -4769138.335165312
#        Else (feature 375 not in {0.0})
#         Predict: 3.3856782432585297E9
#       Else (feature 804 not in {0.0})
#        If (feature 0 <= 4.005)
#         Predict: 7.520244165311604E9
#        Else (feature 0 > 4.005)
#         Predict: -1.0388381198931999E9
#      Else (feature 2084 not in {0.0})
#       Predict: 5.467492579540228E9
#     Else (feature 2837 not in {0.0})
#      Predict: 9.49243699934619E9
#   Tree 5 (weight 0.1):
#     If (feature 109 in {0.0})
#      If (feature 18 in {0.0})
#       If (feature 2837 in {0.0})
#        If (feature 2084 in {0.0})
#         Predict: -6935149.66155468
#        Else (feature 2084 not in {0.0})
#         Predict: 4.373994063632182E9
#       Else (feature 2837 not in {0.0})
#        Predict: 7.593949599476959E9
#      Else (feature 18 not in {0.0})
#       If (feature 0 <= 3.885)
#        If (feature 1 <= 3.975E7)
#         Predict: -3.330544600502714E8
#        Else (feature 1 > 3.975E7)
#         Predict: 8.1654278251545315E9
#       Else (feature 0 > 3.885)
#        If (feature 1 <= 3.325E7)
#         Predict: -3.711344600502714E8
#        Else (feature 1 > 3.325E7)
#         Predict: 1.3654278251545315E9
#     Else (feature 109 not in {0.0})
#      If (feature 1 <= 5.55E7)
#       If (feature 0 <= 3.575)
#        If (feature 0 <= 3.495)
#         Predict: 2.630229698836404E7
#        Else (feature 0 > 3.495)
#         Predict: 4.790229698836404E7
#       Else (feature 0 > 3.575)
#        If (feature 1 <= 3050000.0)
#         Predict: -1.601084586877882E7
#        Else (feature 1 > 3050000.0)
#         Predict: -1.1610845868778821E7
#      Else (feature 1 > 5.55E7)
#       If (feature 4415 in {1.0})
#        Predict: 1.1762062827013222E10
#       Else (feature 4415 not in {1.0})
#        Predict: 1.1762062827013226E10
#   Tree 6 (weight 0.1):
#     If (feature 1 <= 7.25E8)
#      If (feature 1 <= 1.615E8)
#       If (feature 375 in {1.0})
#        If (feature 1 <= 4100000.0)
#         Predict: -1.535971088269582E9
#        Else (feature 1 > 4100000.0)
#         Predict: -1.5226377549362488E9
#       Else (feature 375 not in {1.0})
#        If (feature 1 <= 1.29E7)
#         Predict: -1.0845982174117092E7
#        Else (feature 1 > 1.29E7)
#         Predict: 2.682755210326946E7
#      Else (feature 1 > 1.615E8)
#       If (feature 1154 in {0.0})
#        If (feature 0 <= 2.885)
#         Predict: -4.3587626496454823E8
#        Else (feature 0 > 2.885)
#         Predict: -6.555411466147605E8
#       Else (feature 1154 not in {0.0})
#        Predict: 1.7163519753141564E8
#     Else (feature 1 > 7.25E8)
#      If (feature 375 in {0.0})
#       If (feature 109 in {0.0})
#        If (feature 0 <= 3.125)
#         Predict: 6.464180487880645E8
#        Else (feature 0 > 3.125)
#         Predict: 2.541983412940168E9
#       Else (feature 109 not in {0.0})
#        If (feature 4417 in {0.0})
#         Predict: 9.409650261610577E9
#        Else (feature 4417 not in {0.0})
#         Predict: 9.40965026161058E9
#      Else (feature 375 not in {0.0})
#       Predict: 1.33113480732276E10
#   Tree 7 (weight 0.1):
#     If (feature 804 in {0.0})
#      If (feature 375 in {0.0})
#       If (feature 1 <= 1.79E8)
#        If (feature 1 <= 1.195E8)
#         Predict: 2846787.2750850627
#        Else (feature 1 > 1.195E8)
#         Predict: 1.083755070327074E8
#       Else (feature 1 > 1.79E8)
#        If (feature 109 in {0.0})
#         Predict: -3.190985614795734E8
#        Else (feature 109 not in {0.0})
#         Predict: 7.527720209288463E9
#      Else (feature 375 not in {0.0})
#       If (feature 1 <= 1.31E7)
#        If (feature 0 <= 3.4450000000000003)
#         Predict: -1.2181102039489987E9
#        Else (feature 0 > 3.4450000000000003)
#         Predict: -1.228776870615666E9
#       Else (feature 1 > 1.31E7)
#        Predict: 1.0649078458582073E10
#     Else (feature 804 not in {0.0})
#      If (feature 0 <= 4.005)
#       Predict: 5.50918567959356E9
#      Else (feature 0 > 4.005)
#       Predict: -8.275142695474256E8
#   Tree 8 (weight 0.1):
#     If (feature 1 <= 9.15E8)
#      If (feature 1 <= 1.615E8)
#       If (feature 375 in {1.0})
#        If (feature 1 <= 4100000.0)
#         Predict: -9.830214964925324E8
#        Else (feature 1 > 4100000.0)
#         Predict: -9.744881631591992E8
#       Else (feature 375 not in {1.0})
#        If (feature 1 <= 1.505E7)
#         Predict: -8080728.145725386
#        Else (feature 1 > 1.505E7)
#         Predict: 2.1406505455087952E7
#      Else (feature 1 > 1.615E8)
#       If (feature 0 <= 2.465)
#        If (feature 0 <= 1.8050000000000002)
#         Predict: -5.061703402989812E8
#        Else (feature 0 > 1.8050000000000002)
#         Predict: -2.3748138111386888E7
#       Else (feature 0 > 2.465)
#        If (feature 97 in {0.0})
#         Predict: -4.5366196570103174E8
#        Else (feature 97 not in {0.0})
#         Predict: 2.710683254478226E8
#     Else (feature 1 > 9.15E8)
#      If (feature 375 in {0.0})
#       If (feature 18 in {0.0})
#        If (feature 109 in {0.0})
#         Predict: 1.4284021249003057E9
#        Else (feature 109 not in {0.0})
#         Predict: 6.022176167430771E9
#       Else (feature 18 not in {0.0})
#        If (feature 0 <= 3.875)
#         Predict: 6.087765289831507E9
#        Else (feature 0 > 3.875)
#         Predict: 2.2477652898315067E9
#      Else (feature 375 not in {0.0})
#       Predict: 8.519262766865658E9
#   Tree 9 (weight 0.1):
#     If (feature 1 <= 5.76816E8)
#      If (feature 1 <= 1.515E8)
#       If (feature 375 in {1.0})
#        If (feature 0 <= 3.425)
#         Predict: -7.795905305273591E8
#        Else (feature 0 > 3.425)
#         Predict: -7.86417197194026E8
#       Else (feature 375 not in {1.0})
#        If (feature 1 <= 8100000.0)
#         Predict: -1.0074143271571415E7
#        Else (feature 1 > 8100000.0)
#         Predict: 1.3837719985190313E7
#      Else (feature 1 > 1.515E8)
#       If (feature 929 in {0.0})
#        If (feature 1897 in {0.0})
#         Predict: -3.576065604523128E8
#        Else (feature 1897 not in {0.0})
#         Predict: 4.5729553229048663E8
#       Else (feature 929 not in {0.0})
#        If (feature 4415 in {0.0})
#         Predict: 4.572955322904888E8
#        Else (feature 4415 not in {0.0})
#         Predict: 4.5729553229048884E8
#     Else (feature 1 > 5.76816E8)
#      If (feature 375 in {0.0})
#       If (feature 109 in {0.0})
#        If (feature 804 in {0.0})
#         Predict: 7.827668616032262E8
#        Else (feature 804 not in {0.0})
#         Predict: 4.1216681186947885E9
#       Else (feature 109 not in {0.0})
#        Predict: 4.817740933944618E9
#      Else (feature 375 not in {0.0})
#       Predict: 6.815410213492531E9
#   Tree 10 (weight 0.1):
#     If (feature 2837 in {0.0})
#      If (feature 2084 in {0.0})
#       If (feature 804 in {0.0})
#        If (feature 18 in {0.0})
#         Predict: -2901337.0133518334
#        Else (feature 18 not in {0.0})
#         Predict: 6.988256786266733E8
#       Else (feature 804 not in {0.0})
#        If (feature 0 <= 4.005)
#         Predict: 3.2973344949558296E9
#        Else (feature 0 > 4.005)
#         Predict: -6.583804413544812E8
#      Else (feature 2084 not in {0.0})
#       Predict: 2.6123844833129196E9
#     Else (feature 2837 not in {0.0})
#      Predict: 5.188348911988737E9
#   Tree 11 (weight 0.1):
#     If (feature 1 <= 6.5E8)
#      If (feature 1 <= 1.615E8)
#       If (feature 18 in {1.0})
#        If (feature 1 <= 1.995E7)
#         Predict: -4.522333992446168E8
#        Else (feature 1 > 1.995E7)
#         Predict: -4.254804167292783E8
#       Else (feature 18 not in {1.0})
#        If (feature 375 in {1.0})
#         Predict: -6.26368957019217E8
#        Else (feature 375 not in {1.0})
#         Predict: 3699029.8364083893
#      Else (feature 1 > 1.615E8)
#       If (feature 1154 in {0.0})
#        If (feature 309 in {0.0})
#         Predict: -3.1811026826682395E8
#        Else (feature 309 not in {0.0})
#         Predict: 4.3990229808116657E8
#       Else (feature 1154 not in {0.0})
#        Predict: 3.6396184295438766E8
#     Else (feature 1 > 6.5E8)
#      If (feature 375 in {0.0})
#       If (feature 109 in {0.0})
#        If (feature 0 <= 3.125)
#         Predict: 2.5734961060540274E8
#        Else (feature 0 > 3.125)
#         Predict: 1.180451913955371E9
#       Else (feature 109 not in {0.0})
#        Predict: 3.854773014558365E9
#      Else (feature 375 not in {0.0})
#       Predict: 5.452908438196693E9
#   Tree 12 (weight 0.1):
#     If (feature 1 <= 2.45E9)
#      If (feature 1 <= 1.761E8)
#       If (feature 1 <= 1.215E8)
#        If (feature 1 <= 5.84E7)
#         Predict: 5071106.253008943
#        Else (feature 1 > 5.84E7)
#         Predict: -3.917389203267146E7
#       Else (feature 1 > 1.215E8)
#        If (feature 1704 in {0.0})
#         Predict: 1.1518893785966806E8
#        Else (feature 1704 not in {0.0})
#         Predict: 4.9752435173453015E8
#      Else (feature 1 > 1.761E8)
#       If (feature 395 in {0.0})
#        If (feature 595 in {0.0})
#         Predict: -3.008899315989779E8
#        Else (feature 595 not in {0.0})
#         Predict: 6.750695970634047E8
#       Else (feature 395 not in {0.0})
#        If (feature 0 <= 3.795)
#         Predict: 1.425513811430965E9
#        Else (feature 0 > 3.795)
#         Predict: -5.8856022093342304E7
#     Else (feature 1 > 2.45E9)
#      If (feature 1225 in {1.0})
#       Predict: -1.1144022029170532E9
#      Else (feature 1225 not in {1.0})
#       If (feature 0 <= 3.665)
#        If (feature 684 in {1.0})
#         Predict: -1.114402202917076E9
#        Else (feature 684 not in {1.0})
#         Predict: 2.1991506028546686E9
#       Else (feature 0 > 3.665)
#        If (feature 804 in {1.0})
#         Predict: 2.4017772131735897E9
#        Else (feature 804 not in {1.0})
#         Predict: 4.291032369131922E9
#   Tree 13 (weight 0.1):
#     If (feature 2837 in {0.0})
#      If (feature 2084 in {0.0})
#       If (feature 1 <= 1.761E8)
#        If (feature 1 <= 1.195E8)
#         Predict: 431620.4388523897
#        Else (feature 1 > 1.195E8)
#         Predict: 8.588818535664074E7
#       Else (feature 1 > 1.761E8)
#        If (feature 18 in {0.0})
#         Predict: -1.5723307849432078E8
#        Else (feature 18 not in {0.0})
#         Predict: 1.3359212891706483E9
#      Else (feature 2084 not in {0.0})
#       Predict: 1.4139870832883282E9
#     Else (feature 2837 not in {0.0})
#      Predict: 3.0563822729735317E9
#   Tree 14 (weight 0.1):
#     If (feature 2837 in {0.0})
#      If (feature 804 in {0.0})
#       If (feature 1 <= 1.776E8)
#        If (feature 1 <= 1.215E8)
#         Predict: 454803.46896318573
#        Else (feature 1 > 1.215E8)
#         Predict: 8.075232469984142E7
#       Else (feature 1 > 1.776E8)
#        If (feature 375 in {0.0})
#         Predict: -1.1811396535477458E8
#        Else (feature 375 not in {0.0})
#         Predict: 3.5355668924298325E9
#      Else (feature 804 not in {0.0})
#       If (feature 1 <= 4100000.0)
#        Predict: -5.285447043892389E8
#       Else (feature 1 > 4100000.0)
#        Predict: 1.9528683862377357E9
#     Else (feature 2837 not in {0.0})
#      Predict: 2.445105818378826E9
#   Tree 15 (weight 0.1):
#     If (feature 2956 in {0.0})
#      If (feature 109 in {0.0})
#       If (feature 1 <= 1.79E8)
#        If (feature 1 <= 1.215E8)
#         Predict: 298417.33442841866
#        Else (feature 1 > 1.215E8)
#         Predict: 7.49742200430987E7
#       Else (feature 1 > 1.79E8)
#        If (feature 18 in {0.0})
#         Predict: -1.3709226788602918E8
#        Else (feature 18 not in {0.0})
#         Predict: 1.0923598244074736E9
#      Else (feature 109 not in {0.0})
#       If (feature 1 <= 5.55E7)
#        If (feature 1 <= 3.925E7)
#         Predict: -3889799.5710397395
#        Else (feature 1 > 3.925E7)
#         Predict: 2.3987080030188456E7
#       Else (feature 1 > 5.55E7)
#        Predict: 2.6990576998455734E9
#     Else (feature 2956 not in {0.0})
#      Predict: 2.04075309962985E9
#   Tree 16 (weight 0.1):
#     If (feature 3977 in {0.0})
#      If (feature 2084 in {0.0})
#       If (feature 310 in {0.0})
#        If (feature 2837 in {0.0})
#         Predict: -930429.8309063249
#        Else (feature 2837 not in {0.0})
#         Predict: 1.9835031082802658E9
#       Else (feature 310 not in {0.0})
#        If (feature 0 <= 3.295)
#         Predict: 1.2433131193081145E9
#        Else (feature 0 > 3.295)
#         Predict: -3.533405071655989E7
#      Else (feature 2084 not in {0.0})
#       Predict: 1.1822309132788239E9
#     Else (feature 3977 not in {0.0})
#      Predict: 2.0681715532070556E9
#   Tree 17 (weight 0.1):
#     If (feature 804 in {0.0})
#      If (feature 3977 in {0.0})
#       If (feature 595 in {0.0})
#        If (feature 1 <= 1.761E8)
#         Predict: 1819158.6573986586
#        Else (feature 1 > 1.761E8)
#         Predict: -7.704987023653157E7
#       Else (feature 595 not in {0.0})
#        If (feature 0 <= 3.255)
#         Predict: 1.1731738403314896E9
#        Else (feature 0 > 3.255)
#         Predict: -1.1119599319281705E8
#      Else (feature 3977 not in {0.0})
#       Predict: 1.6545372425656443E9
#     Else (feature 804 not in {0.0})
#      If (feature 0 <= 4.005)
#       Predict: 1.589899248533575E9
#      Else (feature 0 > 4.005)
#       Predict: -4.2270936101209545E8
#   Tree 18 (weight 0.1):
#     If (feature 2084 in {0.0})
#      If (feature 310 in {0.0})
#       If (feature 1 <= 1.79E8)
#        If (feature 18 in {1.0})
#         Predict: -3.531439435954445E8
#        Else (feature 18 not in {1.0})
#         Predict: 2345646.129970816
#       Else (feature 1 > 1.79E8)
#        If (feature 375 in {0.0})
#         Predict: -9.038363540165487E7
#        Else (feature 375 not in {0.0})
#         Predict: 2.8714680275345573E9
#      Else (feature 310 not in {0.0})
#       If (feature 0 <= 3.295)
#        If (feature 0 <= 2.835)
#         Predict: -2.4300098713339913E8
#        Else (feature 0 > 2.835)
#         Predict: 1.8349189033927393E9
#       Else (feature 0 > 3.295)
#        If (feature 0 <= 3.5149999999999997)
#         Predict: 9713242.591835089
#        Else (feature 0 > 3.5149999999999997)
#         Predict: -2.563870482479596E7
#     Else (feature 2084 not in {0.0})
#      Predict: 9.611947046703644E8
#   Tree 19 (weight 0.1):
#     If (feature 2956 in {0.0})
#      If (feature 109 in {0.0})
#       If (feature 2837 in {0.0})
#        If (feature 395 in {0.0})
#         Predict: -936059.3670772839
#        Else (feature 395 not in {0.0})
#         Predict: 5.486239693957318E8
#       Else (feature 2837 not in {0.0})
#        Predict: 1.6202891877518501E9
#      Else (feature 109 not in {0.0})
#       If (feature 1 <= 5.75E7)
#        If (feature 0 <= 3.565)
#         Predict: 1.4641247672939995E7
#        Else (feature 0 > 3.565)
#         Predict: -6786394.534189616
#       Else (feature 1 > 5.75E7)
#        Predict: 2.192918946970276E9
#     Else (feature 2956 not in {0.0})
#      Predict: 1.6662752667976985E9
#   Tree 20 (weight 0.1):
#     If (feature 804 in {0.0})
#      If (feature 595 in {0.0})
#       If (feature 3977 in {0.0})
#        If (feature 1225 in {1.0})
#         Predict: -7.751739010193787E8
#        Else (feature 1225 not in {1.0})
#         Predict: -396430.97244035854
#       Else (feature 3977 not in {0.0})
#        Predict: 1.3418937330062618E9
#      Else (feature 595 not in {0.0})
#       If (feature 0 <= 3.255)
#        Predict: 9.568030112189379E8
#       Else (feature 0 > 3.255)
#        Predict: -7.069285560050702E7
#     Else (feature 804 not in {0.0})
#      If (feature 0 <= 4.005)
#       Predict: 1.2901833377806072E9
#      Else (feature 0 > 4.005)
#       Predict: -3.3844940616225505E8
#   Tree 21 (weight 0.1):
#     If (feature 2956 in {0.0})
#      If (feature 2084 in {0.0})
#       If (feature 836 in {0.0})
#        If (feature 109 in {0.0})
#         Predict: -789917.229426888
#        Else (feature 109 not in {0.0})
#         Predict: 3.310342644549453E8
#       Else (feature 836 not in {0.0})
#        Predict: 6.658524787599223E8
#      Else (feature 2084 not in {0.0})
#       Predict: 7.692222618041954E8
#     Else (feature 2956 not in {0.0})
#      Predict: 1.333099499632647E9
#   Tree 22 (weight 0.1):
#     If (feature 310 in {0.0})
#      If (feature 2837 in {0.0})
#       If (feature 18 in {0.0})
#        If (feature 1 <= 1.761E8)
#         Predict: 1745689.5331922655
#        Else (feature 1 > 1.761E8)
#         Predict: -8.132242694749582E7
#       Else (feature 18 not in {0.0})
#        If (feature 0 <= 3.895)
#         Predict: 2.1041942191419618E9
#        Else (feature 0 > 3.895)
#         Predict: -3.3569975284438014E8
#      Else (feature 2837 not in {0.0})
#       Predict: 1.296468619841854E9
#     Else (feature 310 not in {0.0})
#      If (feature 0 <= 3.3049999999999997)
#       If (feature 0 <= 2.835)
#        Predict: -1.939763081929304E8
#       Else (feature 0 > 2.835)
#        Predict: 1.4683596042279804E9
#      Else (feature 0 > 3.3049999999999997)
#       If (feature 0 <= 3.4850000000000003)
#        Predict: 8195075.5872569755
#       Else (feature 0 > 3.4850000000000003)
#        Predict: -2.008648234604788E7
#   Tree 23 (weight 0.1):
#     If (feature 1251 in {0.0})
#      If (feature 395 in {0.0})
#       If (feature 804 in {0.0})
#        If (feature 595 in {0.0})
#         Predict: -770244.9504920449
#        Else (feature 595 not in {0.0})
#         Predict: 4.295805806152965E8
#       Else (feature 804 not in {0.0})
#        If (feature 0 <= 4.005)
#         Predict: 1.0485691390598698E9
#        Else (feature 0 > 4.005)
#         Predict: -2.709506793905573E8
#      Else (feature 395 not in {0.0})
#       If (feature 0 <= 3.495)
#        Predict: -1.0931104272970885E8
#       Else (feature 0 > 3.495)
#        If (feature 0 <= 3.8049999999999997)
#         Predict: 1.163348659736341E9
#        Else (feature 0 > 3.8049999999999997)
#         Predict: -2.4147207083103657E7
#     Else (feature 1251 not in {0.0})
#      If (feature 0 <= 1.745)
#       Predict: 1.2822749475953069E9
#      Else (feature 0 > 1.745)
#       Predict: -399036.97714710236
#   Tree 24 (weight 0.1):
#     If (feature 1 <= 4.35E8)
#      If (feature 1 <= 1.515E8)
#       If (feature 375 in {1.0})
#        If (feature 0 <= 3.425)
#         Predict: -4.994870375084678E8
#        Else (feature 0 > 3.425)
#         Predict: -5.049483708418012E8
#       Else (feature 375 not in {1.0})
#        If (feature 18 in {1.0})
#         Predict: -2.722059437326827E8
#        Else (feature 18 not in {1.0})
#         Predict: -53419.29094966587
#      Else (feature 1 > 1.515E8)
#       If (feature 2062 in {0.0})
#        If (feature 929 in {0.0})
#         Predict: -1.1867297836493169E8
#        Else (feature 929 not in {0.0})
#         Predict: 6.232203985424525E8
#       Else (feature 2062 not in {0.0})
#        Predict: 6.562850752430406E8
#     Else (feature 1 > 4.35E8)
#      If (feature 375 in {0.0})
#       If (feature 0 <= 3.975)
#        If (feature 18 in {0.0})
#         Predict: 2.933638510725542E8
#        Else (feature 18 not in {0.0})
#         Predict: 2.63097591132641E9
#       Else (feature 0 > 3.975)
#        If (feature 4430 in {0.0})
#         Predict: -4.7943689524615777E8
#        Else (feature 4430 not in {0.0})
#         Predict: 9.653391658698587E8
#      Else (feature 375 not in {0.0})
#       Predict: 2.314017437921036E9
#   Tree 25 (weight 0.1):
#     If (feature 1 <= 4.75E8)
#      If (feature 1 <= 1.515E8)
#       If (feature 1 <= 6950000.0)
#        If (feature 375 in {1.0})
#         Predict: -4.0395869667344093E8
#        Else (feature 375 not in {1.0})
#         Predict: -1.0661761758779246E7
#       Else (feature 1 > 6950000.0)
#        If (feature 1 <= 5.25E7)
#         Predict: 1.509277486931663E7
#        Else (feature 1 > 5.25E7)
#         Predict: -2.1366178287253756E7
#      Else (feature 1 > 1.515E8)
#       If (feature 1897 in {0.0})
#        If (feature 372 in {0.0})
#         Predict: -9.402195858287E7
#        Else (feature 372 not in {0.0})
#         Predict: 8.099354127639999E8
#       Else (feature 1897 not in {0.0})
#        Predict: 6.469549942154388E8
#     Else (feature 1 > 4.75E8)
#      If (feature 109 in {0.0})
#       If (feature 375 in {0.0})
#        If (feature 0 <= 3.975)
#         Predict: 3.0104440417855364E8
#        Else (feature 0 > 3.975)
#         Predict: -3.009908841331553E8
#       Else (feature 375 not in {0.0})
#        Predict: 1.8512139503368301E9
#      Else (feature 109 not in {0.0})
#       Predict: 1.6459533550448074E9
#   Tree 26 (weight 0.1):
#     If (feature 1 <= 6.5E8)
#      If (feature 1 <= 1.615E8)
#       If (feature 1 <= 1.995E7)
#        If (feature 375 in {1.0})
#         Predict: -3.549434483955067E8
#        Else (feature 375 not in {1.0})
#         Predict: -6386681.787301308
#       Else (feature 1 > 1.995E7)
#        If (feature 1 <= 5.55E7)
#         Predict: 2.7812695592752863E7
#        Else (feature 1 > 5.55E7)
#         Predict: -1.932543457354317E7
#      Else (feature 1 > 1.615E8)
#       If (feature 29 in {0.0})
#        If (feature 1154 in {0.0})
#         Predict: -8.401173778017847E7
#        Else (feature 1154 not in {0.0})
#         Predict: 5.2689011340709496E8
#       Else (feature 29 not in {0.0})
#        Predict: 6.36912578875042E8
#     Else (feature 1 > 6.5E8)
#      If (feature 4426 in {1.0})
#       Predict: -1.538289827147771E9
#      Else (feature 4426 not in {1.0})
#       If (feature 109 in {0.0})
#        If (feature 18 in {0.0})
#         Predict: 2.7117371863445324E8
#        Else (feature 18 not in {0.0})
#         Predict: 8.170611195369549E8
#       Else (feature 109 not in {0.0})
#        Predict: 1.3167626840358467E9
#   Tree 27 (weight 0.1):
#     If (feature 1 <= 7.05E8)
#      If (feature 1 <= 5.45E7)
#       If (feature 1 <= 2.9875E7)
#        If (feature 375 in {1.0})
#         Predict: -2.839547587164053E8
#        Else (feature 375 not in {1.0})
#         Predict: -3819495.9287013956
#       Else (feature 1 > 2.9875E7)
#        If (feature 18 in {1.0})
#         Predict: -3.9549930140043104E8
#        Else (feature 18 not in {1.0})
#         Predict: 3.4985983929947756E7
#      Else (feature 1 > 5.45E7)
#       If (feature 2062 in {0.0})
#        If (feature 372 in {0.0})
#         Predict: -2.236641992521579E7
#        Else (feature 372 not in {0.0})
#         Predict: 6.647506777672348E8
#       Else (feature 2062 not in {0.0})
#        Predict: 5.606347994670422E8
#     Else (feature 1 > 7.05E8)
#      If (feature 375 in {0.0})
#       If (feature 4426 in {1.0})
#        Predict: -1.230631861718217E9
#       Else (feature 4426 not in {1.0})
#        If (feature 1225 in {1.0})
#         Predict: -5.0171179084106445E8
#        Else (feature 1225 not in {1.0})
#         Predict: 3.4301202274400175E8
#      Else (feature 375 not in {0.0})
#       Predict: 1.426736416542572E9
#   Tree 28 (weight 0.1):
#     If (feature 1 <= 1.825E8)
#      If (feature 1 <= 1.215E8)
#       If (feature 18 in {1.0})
#        If (feature 1 <= 3.35E7)
#         Predict: -1.5391275359498534E8
#        Else (feature 1 > 3.35E7)
#         Predict: -5.601968383189793E8
#       Else (feature 18 not in {1.0})
#        If (feature 1 <= 2.225E7)
#         Predict: -4034318.6390472865
#        Else (feature 1 > 2.225E7)
#         Predict: 1.0327559463234235E7
#      Else (feature 1 > 1.215E8)
#       If (feature 421 in {0.0})
#        If (feature 43 in {0.0})
#         Predict: 1.0708904199602985E8
#        Else (feature 43 not in {0.0})
#         Predict: 6.995614684270439E8
#       Else (feature 421 not in {0.0})
#        Predict: 8.500154360216522E8
#     Else (feature 1 > 1.825E8)
#      If (feature 18 in {0.0})
#       If (feature 109 in {0.0})
#        If (feature 375 in {0.0})
#         Predict: -1.5850995526467222E8
#        Else (feature 375 not in {0.0})
#         Predict: 1.1413891332340584E9
#       Else (feature 109 not in {0.0})
#        Predict: 9.848077426798744E8
#      Else (feature 18 not in {0.0})
#       If (feature 0 <= 3.885)
#        Predict: 1.8125572197692268E9
#       Else (feature 0 > 3.885)
#        If (feature 0 <= 4.005)
#         Predict: -1.5738547140466151E9
#        Else (feature 0 > 4.005)
#         Predict: 8.171712902337285E8
#   Tree 29 (weight 0.1):
#     If (feature 1 <= 1.825E8)
#      If (feature 1 <= 1.215E8)
#       If (feature 1 <= 5.84E7)
#        If (feature 1 <= 3.4074085E7)
#         Predict: -1965000.5603754441
#        Else (feature 1 > 3.4074085E7)
#         Predict: 3.728954444190655E7
#       Else (feature 1 > 5.84E7)
#        If (feature 1 <= 8.9E7)
#         Predict: -4.219414587893329E7
#        Else (feature 1 > 8.9E7)
#         Predict: 1.7440274938086867E7
#      Else (feature 1 > 1.215E8)
#       If (feature 469 in {0.0})
#        If (feature 27 in {0.0})
#         Predict: 8.720535406133232E7
#        Else (feature 27 not in {0.0})
#         Predict: 8.285976276224442E8
#       Else (feature 469 not in {0.0})
#        Predict: 8.285976276224453E8
#     Else (feature 1 > 1.825E8)
#      If (feature 18 in {0.0})
#       If (feature 310 in {0.0})
#        If (feature 109 in {0.0})
#         Predict: -1.311903034273437E8
#        Else (feature 109 not in {0.0})
#         Predict: 7.87846194143898E8
#       Else (feature 310 not in {0.0})
#        If (feature 0 <= 3.3049999999999997)
#         Predict: 9.64824924099505E8
#        Else (feature 0 > 3.3049999999999997)
#         Predict: 7.960147309683354E7
#      Else (feature 18 not in {0.0})
#       If (feature 0 <= 3.885)
#        Predict: 1.450045775815382E9
#       Else (feature 0 > 3.885)
#        If (feature 0 <= 4.005)
#         Predict: -1.2590837712372923E9
#        Else (feature 0 > 4.005)
#         Predict: 6.537370321869829E8
#   Tree 30 (weight 0.1):
#     If (feature 1 <= 3.75E9)
#      If (feature 1 <= 1.761E8)
#       If (feature 1287 in {0.0})
#        If (feature 18 in {1.0})
#         Predict: -1.6097570485558307E8
#        Else (feature 18 not in {1.0})
#         Predict: 977372.6230511783
#       Else (feature 1287 not in {0.0})
#        If (feature 4418 in {0.0})
#         Predict: 4.4070187546780354E8
#        Else (feature 4418 not in {0.0})
#         Predict: 4.407018754678036E8
#      Else (feature 1 > 1.761E8)
#       If (feature 0 <= 2.545)
#        If (feature 557 in {0.0})
#         Predict: 1.1126877539675488E8
#        Else (feature 557 not in {0.0})
#         Predict: 1.5986502489978962E9
#       Else (feature 0 > 2.545)
#        If (feature 395 in {0.0})
#         Predict: -7.638153396495847E7
#        Else (feature 395 not in {0.0})
#         Predict: 5.454292017918673E8
#     Else (feature 1 > 3.75E9)
#      If (feature 18 in {0.0})
#       If (feature 0 <= 2.955)
#        Predict: -1.04127387224086E9
#       Else (feature 0 > 2.955)
#        If (feature 1225 in {1.0})
#         Predict: -3.4342938093444824E8
#        Else (feature 1225 not in {1.0})
#         Predict: 5.376973409898015E8
#      Else (feature 18 not in {0.0})
#       Predict: 1.1600366206523056E9
#   Tree 31 (weight 0.1):
#     If (feature 3977 in {0.0})
#      If (feature 2956 in {0.0})
#       If (feature 2921 in {1.0})
#        Predict: -6.438069777095275E8
#       Else (feature 2921 not in {1.0})
#        If (feature 1897 in {0.0})
#         Predict: -142429.56980163808
#        Else (feature 1897 not in {0.0})
#         Predict: 5.1525705449494886E8
#      Else (feature 2956 not in {0.0})
#       Predict: 9.143956932911978E8
#     Else (feature 3977 not in {0.0})
#      Predict: 9.215890634359746E8
#   Tree 32 (weight 0.1):
#     If (feature 1 <= 7.05E8)
#      If (feature 929 in {0.0})
#       If (feature 1 <= 5.55E7)
#        If (feature 1 <= 3.96E7)
#         Predict: -1154100.3814131885
#        Else (feature 1 > 3.96E7)
#         Predict: 3.4339298277934894E7
#       Else (feature 1 > 5.55E7)
#        If (feature 1154 in {0.0})
#         Predict: -1.8154891535931263E7
#        Else (feature 1154 not in {0.0})
#         Predict: 4.0243128820619774E8
#      Else (feature 929 not in {0.0})
#       If (feature 4415 in {0.0})
#        Predict: 5.151022555870937E8
#       Else (feature 4415 not in {0.0})
#        Predict: 5.151022555870936E8
#     Else (feature 1 > 7.05E8)
#      If (feature 0 <= 3.875)
#       If (feature 0 <= 3.665)
#        If (feature 684 in {1.0})
#         Predict: -1.0498078268709335E9
#        Else (feature 684 not in {1.0})
#         Predict: 2.4708369935900825E8
#       Else (feature 0 > 3.665)
#        If (feature 3910 in {1.0})
#         Predict: 5.0221508204432964E7
#        Else (feature 3910 not in {1.0})
#         Predict: 8.110951782713933E8
#      Else (feature 0 > 3.875)
#       If (feature 0 <= 3.995)
#        If (feature 804 in {0.0})
#         Predict: -7.167406246454612E8
#        Else (feature 804 not in {0.0})
#         Predict: 5.475655813763885E8
#       Else (feature 0 > 3.995)
#        If (feature 0 <= 4.215)
#         Predict: 3.9953626724390405E8
#        Else (feature 0 > 4.215)
#         Predict: -2.747150188336029E8
#   Tree 33 (weight 0.1):
#     If (feature 1 <= 7.75E8)
#      If (feature 1897 in {0.0})
#       If (feature 929 in {0.0})
#        If (feature 82 in {1.0})
#         Predict: -1.6533533687537003E8
#        Else (feature 82 not in {1.0})
#         Predict: -1022044.4799717034
#       Else (feature 929 not in {0.0})
#        If (feature 4415 in {0.0})
#         Predict: 4.12081804469675E8
#        Else (feature 4415 not in {0.0})
#         Predict: 4.1208180446967494E8
#      Else (feature 1897 not in {0.0})
#       Predict: 4.158366219031455E8
#     Else (feature 1 > 7.75E8)
#      If (feature 2921 in {1.0})
#       Predict: -5.64462322039424E8
#      Else (feature 2921 not in {1.0})
#       If (feature 3996 in {1.0})
#        Predict: -8.824073517505264E8
#       Else (feature 3996 not in {1.0})
#        If (feature 684 in {1.0})
#         Predict: -8.398462614967499E8
#        Else (feature 684 not in {1.0})
#         Predict: 2.4363283681215835E8
#   Tree 34 (weight 0.1):
#     If (feature 1 <= 1.825E8)
#      If (feature 1 <= 1.215E8)
#       If (feature 1 <= 4220000.0)
#        If (feature 375 in {1.0})
#         Predict: -1.9391921171485874E8
#        Else (feature 375 not in {1.0})
#         Predict: -6507377.2374588195
#       Else (feature 1 > 4220000.0)
#        If (feature 1 <= 5.75E7)
#         Predict: 6474775.17249495
#        Else (feature 1 > 5.75E7)
#         Predict: -1.1813071333659457E7
#      Else (feature 1 > 1.215E8)
#       If (feature 861 in {0.0})
#        If (feature 421 in {0.0})
#         Predict: 6.896343706987423E7
#        Else (feature 421 not in {0.0})
#         Predict: 6.817114579151865E8
#       Else (feature 861 not in {0.0})
#        Predict: 8.302967367203114E8
#     Else (feature 1 > 1.825E8)
#      If (feature 310 in {0.0})
#       If (feature 1251 in {0.0})
#        If (feature 375 in {0.0})
#         Predict: -1.0223567221269535E8
#        Else (feature 375 not in {0.0})
#         Predict: 7.032045641775055E8
#       Else (feature 1251 not in {0.0})
#        Predict: 7.216726340891123E8
#      Else (feature 310 not in {0.0})
#       If (feature 0 <= 3.295)
#        Predict: 6.890214247523222E8
#       Else (feature 0 > 3.295)
#        Predict: 8.282135838759935E7
#   Tree 35 (weight 0.1):
#     If (feature 1 <= 1.79E8)
#      If (feature 1 <= 8.75E7)
#       If (feature 1 <= 5.84E7)
#        If (feature 1 <= 3.975E7)
#         Predict: -951322.6463428575
#        Else (feature 1 > 3.975E7)
#         Predict: 2.948871142010893E7
#       Else (feature 1 > 5.84E7)
#        If (feature 1 <= 6.95E7)
#         Predict: -4.2197525002102144E7
#        Else (feature 1 > 6.95E7)
#         Predict: -1.4864422182602106E7
#      Else (feature 1 > 8.75E7)
#       If (feature 43 in {0.0})
#        If (feature 997 in {0.0})
#         Predict: 2.2234179219610676E7
#        Else (feature 997 not in {0.0})
#         Predict: 4.3057758664635974E8
#       Else (feature 43 not in {0.0})
#        If (feature 0 <= 3.3049999999999997)
#         Predict: 5.475555964255269E8
#        Else (feature 0 > 3.3049999999999997)
#         Predict: 3.877201016151047E7
#     Else (feature 1 > 1.79E8)
#      If (feature 1251 in {0.0})
#       If (feature 310 in {0.0})
#        If (feature 375 in {0.0})
#         Predict: -4.553251904357272E7
#        Else (feature 375 not in {0.0})
#         Predict: 5.625636513420029E8
#       Else (feature 310 not in {0.0})
#        If (feature 0 <= 3.3049999999999997)
#         Predict: 5.51217139801858E8
#        Else (feature 0 > 3.3049999999999997)
#         Predict: 6.625708671007943E7
#      Else (feature 1251 not in {0.0})
#       Predict: 5.773381072712898E8
#   Tree 36 (weight 0.1):
#     If (feature 1 <= 3.75E9)
#      If (feature 18 in {1.0})
#       If (feature 0 <= 4.005)
#        If (feature 1 <= 3.975E7)
#         Predict: -2.130413164647498E8
#        Else (feature 1 > 3.975E7)
#         Predict: -8.677870284649677E8
#       Else (feature 0 > 4.005)
#        If (feature 1 <= 2.505E7)
#         Predict: -1.0249402483137465E8
#        Else (feature 1 > 2.505E7)
#         Predict: 4.3921423589657915E8
#      Else (feature 18 not in {1.0})
#       If (feature 469 in {0.0})
#        If (feature 2062 in {0.0})
#         Predict: -395342.4083843698
#        Else (feature 2062 not in {0.0})
#         Predict: 3.865728947946908E8
#       Else (feature 469 not in {0.0})
#        If (feature 0 <= 3.085)
#         Predict: 6.773320984028286E8
#        Else (feature 0 > 3.085)
#         Predict: 1.1599641973835011E8
#     Else (feature 1 > 3.75E9)
#      If (feature 18 in {0.0})
#       If (feature 0 <= 2.955)
#        Predict: -6.763722431491699E8
#       Else (feature 0 > 2.955)
#        If (feature 684 in {1.0})
#         Predict: -6.423233709461517E8
#        Else (feature 684 not in {1.0})
#         Predict: 2.7885550765728354E8
#      Else (feature 18 not in {0.0})
#       Predict: 7.466658176703472E8
#   Tree 37 (weight 0.1):
#     If (feature 1 <= 5.76816E8)
#      If (feature 1154 in {0.0})
#       If (feature 1704 in {0.0})
#        If (feature 1584 in {0.0})
#         Predict: -1054948.7745797331
#        Else (feature 1584 not in {0.0})
#         Predict: 4.362098192841139E8
#       Else (feature 1704 not in {0.0})
#        Predict: 3.597427365091417E8
#      Else (feature 1154 not in {0.0})
#       Predict: 3.175423243373699E8
#     Else (feature 1 > 5.76816E8)
#      If (feature 557 in {0.0})
#       If (feature 2921 in {1.0})
#        Predict: -4.219371508986087E8
#       Else (feature 2921 not in {1.0})
#        If (feature 0 <= 4.215)
#         Predict: 1.2083304599988589E8
#        Else (feature 0 > 4.215)
#         Predict: -2.9471604570951843E8
#      Else (feature 557 not in {0.0})
#       Predict: 1.2104380846109734E9
#   Tree 38 (weight 0.1):
#     If (feature 1 <= 1.85E9)
#      If (feature 18 in {1.0})
#       If (feature 1 <= 3.325E7)
#        If (feature 1 <= 2.505E7)
#         Predict: -8.178423011018378E7
#        Else (feature 1 > 2.505E7)
#         Predict: 3.2946925309351027E7
#       Else (feature 1 > 3.325E7)
#        If (feature 4426 in {0.0})
#         Predict: -7.794822431827534E8
#        Else (feature 4426 not in {0.0})
#         Predict: -2.5121902972151446E8
#      Else (feature 18 not in {1.0})
#       If (feature 786 in {1.0})
#        Predict: -2.6686113896118793E8
#       Else (feature 786 not in {1.0})
#        If (feature 3073 in {0.0})
#         Predict: -461328.60153407993
#        Else (feature 3073 not in {0.0})
#         Predict: 4.164208090390301E8
#     Else (feature 1 > 1.85E9)
#      If (feature 1225 in {1.0})
#       Predict: -2.357728365676117E8
#      Else (feature 1225 not in {1.0})
#       If (feature 0 <= 2.955)
#        Predict: -5.65264403719307E8
#       Else (feature 0 > 2.955)
#        If (feature 684 in {1.0})
#         Predict: -5.380253059568939E8
#        Else (feature 684 not in {1.0})
#         Predict: 4.147101972714645E8
#   Tree 39 (weight 0.1):
#     If (feature 1 <= 1.79E8)
#      If (feature 1 <= 8.55E7)
#       If (feature 1 <= 5.75E7)
#        If (feature 1 <= 2.505E7)
#         Predict: -1723374.7050228964
#        Else (feature 1 > 2.505E7)
#         Predict: 1.5630037932831464E7
#       Else (feature 1 > 5.75E7)
#        If (feature 754 in {0.0})
#         Predict: -1.9521465952170197E7
#        Else (feature 754 not in {0.0})
#         Predict: 1.2723793495820999E8
#      Else (feature 1 > 8.55E7)
#       If (feature 63 in {0.0})
#        If (feature 43 in {0.0})
#         Predict: 1.6232117738658413E7
#        Else (feature 43 not in {0.0})
#         Predict: 2.6398671437822968E8
#       Else (feature 63 not in {0.0})
#        If (feature 0 <= 3.565)
#         Predict: 4.025465865943156E8
#        Else (feature 0 > 3.565)
#         Predict: -5.48174034388868E7
#     Else (feature 1 > 1.79E8)
#      If (feature 89 in {0.0})
#       If (feature 372 in {0.0})
#        If (feature 469 in {0.0})
#         Predict: -5.208924983104055E7
#        Else (feature 469 not in {0.0})
#         Predict: 2.2140568924635532E8
#       Else (feature 372 not in {0.0})
#        Predict: 5.077779832640866E8
#      Else (feature 89 not in {0.0})
#       If (feature 0 <= 3.8049999999999997)
#        Predict: 8.259928770719509E8
#       Else (feature 0 > 3.8049999999999997)
#        Predict: -1.667688732408811E8

# %%
import pandas as pd
def ExtractFeatureImp(featureImp, dataset, featuresCol):
    list_extract = []
    for i in dataset.schema[featuresCol].metadata["ml_attr"]["attrs"]:
        list_extract = list_extract + dataset.schema[featuresCol].metadata["ml_attr"]["attrs"][i]
    varlist = pd.DataFrame(list_extract)
    varlist['score'] = varlist['idx'].apply(lambda x: featureImp[x])
    return(varlist.sort_values('score', ascending = False))

ExtractFeatureImp(gbt_model.featureImportances, train_df, "features").head(50)
#print(rf_model.featureImportances)
# Out:
#        idx                                               name     score
# 0        0                         continuous_features_rating  0.249237
# 374    374            director_indexed_encoded_Chan-wook Park  0.050678
# 4424  4424                     genres_indexed_encoded_Mystery  0.033493
# 108    108              director_indexed_encoded_Bong Joon Ho  0.032679
# 4417  4417                      genres_indexed_encoded_Action  0.022335
# 2083  2083             director_indexed_encoded_Ajay Pannalal  0.021404
# 3976  3976                  director_indexed_encoded_Jung Huh  0.020639
# 2955  2955              director_indexed_encoded_Lajos Koltai  0.020469
# 17      17            director_indexed_encoded_Hayao Miyazaki  0.020276
# 835    835              director_indexed_encoded_Rohit Shetty  0.019701
# 594    594   director_indexed_encoded_S. Shankar (as Shankar)  0.017595
# 394    394              director_indexed_encoded_Mamoru Oshii  0.017197
# 3909  3909            director_indexed_encoded_Chang-dong Lee  0.016888
# 1210  1210           director_indexed_encoded_Katsuhiro Ôtomo  0.016179
# 2920  2920               director_indexed_encoded_János Szász  0.015777
# 697    697     director_indexed_encoded_Sanjay Leela Bhansali  0.015548
# 803    803             director_indexed_encoded_Isao Takahata  0.015286
# 2765  2765              director_indexed_encoded_Biyi Bandele  0.014739
# 593    593                  director_indexed_encoded_Siddique  0.013505
# 1224  1224              director_indexed_encoded_Yong-hwa Kim  0.013405
# 3071  3071               director_indexed_encoded_Sohail Khan  0.013150
# 2342  2342            director_indexed_encoded_Boyapati Srinu  0.013146
# 114    114             director_indexed_encoded_Rakesh Roshan  0.012675
# 1496  1496               director_indexed_encoded_Abhinay Deo  0.012579
# 2935  2935        director_indexed_encoded_Trivikram Srinivas  0.011513
# 309    309            director_indexed_encoded_S.S. Rajamouli  0.011285
# 902    902           director_indexed_encoded_Surrender Reddy  0.010481
# 817    817  director_indexed_encoded_Gautham Vasudev Menon...  0.010327
# 1678  1678           director_indexed_encoded_Vikram K. Kumar  0.010163
# 1835  1835           director_indexed_encoded_Rajesh M. Selva  0.009989
# 556    556        director_indexed_encoded_Sooraj R. Barjatya  0.009851
# 842    842             director_indexed_encoded_Sreenu Vaitla  0.009832
# 468    468                director_indexed_encoded_K.V. Anand  0.009742
# 1250  1250                director_indexed_encoded_Kabir Khan  0.009727
# 509    509               director_indexed_encoded_Prabhu Deva  0.009248
# 223    223           director_indexed_encoded_A.R. Murugadoss  0.008934
# 928    928               director_indexed_encoded_Atlee Kumar  0.008549
# 1406  1406               director_indexed_encoded_Zoya Akhtar  0.008310
# 659    659             director_indexed_encoded_Venkat Prabhu  0.007597
# 997    997               director_indexed_encoded_Arbaaz Khan  0.006995
# 2058  2058          director_indexed_encoded_Luchino Visconti  0.006836
# 3520  3520          director_indexed_encoded_Kornél Mundruczó  0.006727
# 563    563             director_indexed_encoded_Sanjay Gadhvi  0.006539
# 808    808             director_indexed_encoded_Vishnuvardhan  0.006518
# 1234  1234             director_indexed_encoded_Anand Shankar  0.006469
# 4425  4425                    genres_indexed_encoded_Children  0.006298
# 4415  4415                      genres_indexed_encoded_Comedy  0.006281
# 831    831               director_indexed_encoded_Anurag Basu  0.006232
# 4423  4423                     genres_indexed_encoded_Fantasy  0.006031
# 4431  4431                        genres_indexed_encoded_IMAX  0.005894

# %%
### PMML EXAMPLE
#formula            = RFormula(formula = "budgetvalue ~ .")
#gbt                = GBTRegressor(featuresCol='features', labelCol='budgetvalue',seed=9)
#join_pipeline_gbt  = [formula, gbt]
#gbt_pipeline       = Pipeline(stages = join_pipeline_gbt)
#gbt_final          = gbt_pipeline.fit(train_df_2) 
#
#
#### EXPORTING THE MODEL
#PMMLBuilder(sc, data_df, gbt_final) \
#    .putOption(gbt, "compact", True) \
#    .putOption(gbt, "keep_predictionCol", True) \
#    .buildFile("gbt_budget.pmml")
